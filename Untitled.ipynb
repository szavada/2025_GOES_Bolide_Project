# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ast import literal_eval

# %%
bd= pd.read_csv('datafixed_bolide_data.csv') #the index for bolide 1 is 12

# %%
bolidepathg16=[]

for i in range(len(bd)):
    xg16= np.abs(literaleval(bd.iloc[i]['lat_stereo_g16'])[-1] - literaleval(bd.iloc[i]['lat_stereo_g16'])[0])
    bolidepathg16.append(
# Out:
# 315

# %%
bd.iloc[0]
# Out:
# Unnamed: 0                                       0
# datetime          2019-11-18,05:00:17.215231+00:00
# longitude                               -42.377636
# latitude                                  5.358626
# source                                glm-pipeline
#                                 ...
# moon_fullness                             0.571313
# solarhour                                 2.429243
# sun_alt_obs                             -51.934703
# sun_alt_app                             -51.934703
# date_retrieved                7/22/2025,2:48:16,AM
# Name: 0, Length: 90, dtype: object
