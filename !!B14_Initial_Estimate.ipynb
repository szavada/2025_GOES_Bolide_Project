# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ast import literal_eval

# %%
bd= pd.read_csv('datafixed_bolide_data.csv') #the index for bolide 1 is 12

# %%
b14= bd.iloc[301]

# %%
b14['datetime']
# Out:
# '2020-09-10,08:35:45.039293+00:00'

# %%
lat= literal_eval(b14['lat_stereo_g17'])
long= literal_eval(b14['lon_stereo_g17'])
alt= literal_eval(b14['alt_stereo_g17'])
energy = literal_eval(b14['energyJoules_stereo_g17'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 lat= literal_eval(b14['lat_stereo_g17'])
#       2 long= literal_eval(b14['lon_stereo_g17'])
#       3 alt= literal_eval(b14['alt_stereo_g17'])
#
# File ~\anaconda3\Lib\ast.py:112, in literal_eval(node_or_string)
#     110                 return left - right
#     111     return _convert_signed_num(node)
# --> 112 return _convert(node_or_string)
#
# File ~\anaconda3\Lib\ast.py:111, in literal_eval.<locals>._convert(node)
#     109         else:
#     110             return left - right
# --> 111 return _convert_signed_num(node)
#
# File ~\anaconda3\Lib\ast.py:85, in literal_eval.<locals>._convert_signed_num(node)
#      83     else:
#      84         return - operand
# ---> 85 return _convert_num(node)
#
# File ~\anaconda3\Lib\ast.py:76, in literal_eval.<locals>._convert_num(node)
# ...

# %%
b14['longitude']
