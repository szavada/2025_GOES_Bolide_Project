# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ast import literal_eval

# %%
lat= [45, 45.2, 45.4, 45.6, 45.8, 46]
long= [-120, -120.2, -120.4, -120.6, -120.8, -121]
alt= [60, 58, 56, 54, 52, 50]

# %%
def findtheta(lat, long, alt):
    x= np.abs(lat[-1]-lat[0])*0.0175
    y= np.abs(long[-1]-long[0])*0.0175
    z= np.abs(alt[-1]-alt[0])
    return np.arctan((np.sqrt(x**2+y**2))/z)

def degtom (lat1, long1, lat2, long2, r= 6371): #haversine equation?
    lat1rad = np.radians(lat1)
    long1rad = np.radians(long1)
    lat2rad = np.radians(lat2)
    long2rad = np.radians(long2)
    dlat = lat2rad - lat1rad
    dlong = long2rad - long1rad
#   for i in range(len(lat)):
#       if lat[i] == lat1:
#           errorindex= i

    a= np.sin(dlat/2)**2 + np.cos(lat1rad)*np.cos(lat2rad)*np.sin(dlong/2)**2
    
    #errorla1= -np.cos(dlat/2)**2*np.sin(dlat/2)**2-np.sin(lat1)*np.cos(lat2)*np.sin(dlong/2)**2
    #errorla2= np.cos(dlat/2)**2*np.sin(dlat/2)**2-np.cos(lat1)*np.sin(lat2)*np.sin(dlong/2**2)
    #errorlo1= np.cos(lat1)*np.cos(lat2)*np.cos(dlong/2)*np.sin(dlong/2)
    #errorlo2= -np.cos(lat1)*np.cos(lat2)*np.cos(dlong/2)*np.sin(dlong/2)
    #errordegtom= np.sqrt(errorla1**2*errorlat**2+errorla2**2*errorlat**2+errorlo1**2*errorlong**2+errorlo2**2*errorlong)
    
    b= 2*np.arcsin(np.sqrt(a))
    return r*b*1000#, errordegtom

def airrho(z, H=8500): #calculates density based on rho naught, height, and scale height
                                    #8.5 km is the scale height for Earth and 1.225 kg/m^3 is the density of air at sea level
    return (rho0*(1/(np.e**(z/H))))
    
bestfit= [] #bestfit must be defined outside of the function so that it can be used as a variable

H=8500 #meters
rho0= 1.225 #kg/m^3
rockyrho = 3500 #kg/m^3
metalrho = 7500 #kg/m^3 #constants for bolide density based on possible composition
icyrho = 750 #kg/m^3

# %%
totaldlatlong= 0
for i in range(len(lat)-1):
    totaldlatlong+= degtom(lat[i], long[i], lat[i+1], long[i+1])
    print(degtom(lat[i], long[i], lat[i+1], long[i+1])) #
# Out:
# 27221.21196747691
# 27189.483986798503
# 27157.721262670486
# 27125.925223837025
# 27094.09730543393

# %%
totaldlatlong
# Out:
# 135788.43974621687

# %%
totalmass= 0 #error with conversion? SIGNIFICANTLY larger
totalh= 0 
totalerror= 0

for i in range (5): 
    deltalatlong = np.abs(degtom(lat[i], long[i], lat[i+1], long[i+1])) #change in lat converted to meters 
    #errordeltalatlong= degtom(lat[i], long[i], lat[i+1], long[i+1])[1]
    deltaalt = (np.abs(alt[i+1]-alt[i]))*1000 #multipled by 1000 to convert to meters
    #erroralt1= 1000*((alt[i]-alt[i+1])/np.abs(alt[i+1]-alt[i]))
    #erroralt2= 1000*((alt[i+1]-alt[i])/np.abs(alt[i]-alt[i+1]))
    #errordalt= np.sqrt(erroralt1**2*(erroralt[i]*1000)**2+erroralt2**2*(erroralt[i+1]*1000)**2)
    h= np.sqrt(deltalatlong**2 + deltaalt**2)
    print(h)
    #edll = errordeltalatlong/(np.sqrt(errordeltalatlong**2+errordalt**2)) #not multiplied by an additional error so sigmax^^2=1?? 
    #edalt= errordalt/(np.sqrt(errordeltalatlong**2+errordalt**2)) #this is almost 1 beccause errordalt is so large
    #errorh= np.sqrt(edll**2+edalt**2) #same here because edll is very small
    
    totalh= totalh+h 

    altm = (alt[i]+alt[i+1])*1000
    #erroraltm1= (1000*alt[i+1])/2
    #erroraltm2= (1000*alt[i])/2
    #errorrho= np.sqrt(erroraltm1**2*(erroralt[i]*1000)**2+erroraltm2**2*(erroralt[i+1]*1000)**2)
    
    rho = airrho((1/2)*altm)
    totalmass = totalmass+(h*rho)
    #totalerror= totalerror+(np.sqrt(errorrho**2+errorh**2)) #or do we not need to calculate separately for h and it's error of deltalatlong, alt, and altm?
# Out:
# 27294.585195205076
# 27262.942604722113
# 27231.26556333555
# 27199.555497272337
# 27167.81383910605

# %%
rrocky = (3/4)*(totalmass/rockyrho) #+- totalerror
rmetal = (3/4)*(totalmass/metalrho)
ricy = (3/4)*(totalmass/icyrho)

print (rrocky, rmetal, ricy) #this unit is METERS
# Out:
# 0.058419143110383 0.0272622667848454 0.272622667848454

# %%
#these calculations match my hand calculations!!
