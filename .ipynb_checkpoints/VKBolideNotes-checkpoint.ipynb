# %% [markdown]
# ### The Beginning: Install Packages

# %% [markdown]
# !pip install watermark
# %reload_ext autoreload
# %autoreload 2
# !pip install --upgrade numpy==1.26.3
# %load_ext watermark

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Get dataframe (bdf) --> Make sure you know what kinds of data is here and how to use it via Github's tutorial file

# %%
# !pip install bolides
from bolides import BolideDataFrame;
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: bolides in /home/veke6950/.local/lib/python3.11/site-packages (0.5.0)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from bolides) (4.67.1)
# Requirement already satisfied: numpy in /home/veke6950/.local/lib/python3.11/site-packages (from bolides) (1.26.3)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from bolides) (2.2.2)
# Requirement already satisfied: ephem in /home/veke6950/.local/lib/python3.11/site-packages (from bolides) (4.2)
# Requirement already satisfied: geopandas in /home/veke6950/.local/lib/python3.11/site-packages (from bolides) (1.0.1)
# Requirement already satisfied: matplotlib in /home/veke6950/.local/lib/python3.11/site-packages (from bolides) (3.10.1)
# Requirement already satisfied: lightkurve in /home/veke6950/.local/lib/python3.11/site-packages (from bolides) (2.5.0)
# Requirement already satisfied: netCDF4 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from bolides) (1.7.2)
# Requirement already satisfied: pyproj in /home/veke6950/.local/lib/python3.11/site-packages (from bolides) (3.7.1)
# Requirement already satisfied: astropy in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from bolides) (7.0.0)
# Requirement already satisfied: simplekml in /home/veke6950/.local/lib/python3.11/site-packages (from bolides) (1.3.6)
# Requirement already satisfied: scikit-learn in /home/veke6950/.local/lib/python3.11/site-packages (from bolides) (1.6.1)
# Requirement already satisfied: watermark in /home/veke6950/.local/lib/python3.11/site-packages (from bolides) (2.5.0)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from bolides) (4.12.3)
# Requirement already satisfied: plotly in /home/veke6950/.local/lib/python3.11/site-packages (from bolides) (6.0.0)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from astropy->bolides) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2024.10.28.0.34.7 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from astropy->bolides) (0.2024.12.2.0.35.34)
# Requirement already satisfied: PyYAML>=6.0.0 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from astropy->bolides) (6.0.2)
# Requirement already satisfied: packaging>=22.0.0 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from astropy->bolides) (24.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from beautifulsoup4->bolides) (2.5)
# Requirement already satisfied: pyogrio>=0.7.2 in /home/veke6950/.local/lib/python3.11/site-packages (from geopandas->bolides) (0.10.0)
# Requirement already satisfied: shapely>=2.0.0 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from geopandas->bolides) (2.0.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from pandas->bolides) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from pandas->bolides) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from pandas->bolides) (2024.2)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from pyproj->bolides) (2024.12.14)
# Requirement already satisfied: astroquery>=0.3.10 in /home/veke6950/.local/lib/python3.11/site-packages (from lightkurve->bolides) (0.4.9.post1)
# Requirement already satisfied: bokeh>=2.3.2 in /home/veke6950/.local/lib/python3.11/site-packages (from lightkurve->bolides) (3.6.3)
# Requirement already satisfied: fbpca>=1.0 in /home/veke6950/.local/lib/python3.11/site-packages (from lightkurve->bolides) (1.0)
# Requirement already satisfied: memoization>=0.3.1 in /home/veke6950/.local/lib/python3.11/site-packages (from lightkurve->bolides) (0.4.0)
# Requirement already satisfied: oktopus>=0.1.2 in /home/veke6950/.local/lib/python3.11/site-packages (from lightkurve->bolides) (0.1.2)
# Requirement already satisfied: patsy>=0.5.0 in /home/veke6950/.local/lib/python3.11/site-packages (from lightkurve->bolides) (1.0.1)
# Requirement already satisfied: requests>=2.22.0 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from lightkurve->bolides) (2.32.3)
# Requirement already satisfied: s3fs>=2024.6.1 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from lightkurve->bolides) (2024.10.0)
# Requirement already satisfied: uncertainties>=3.1.4 in /home/veke6950/.local/lib/python3.11/site-packages (from lightkurve->bolides) (3.2.2)
# Requirement already satisfied: urllib3>=1.23 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from lightkurve->bolides) (2.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from matplotlib->bolides) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from matplotlib->bolides) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from matplotlib->bolides) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from matplotlib->bolides) (1.4.7)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from matplotlib->bolides) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from matplotlib->bolides) (3.2.0)
# Requirement already satisfied: scipy>=1.6.0 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from scikit-learn->bolides) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from scikit-learn->bolides) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/veke6950/.local/lib/python3.11/site-packages (from scikit-learn->bolides) (3.5.0)
# Requirement already satisfied: cftime in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from netCDF4->bolides) (1.6.4.post1)
# Requirement already satisfied: narwhals>=1.15.1 in /home/veke6950/.local/lib/python3.11/site-packages (from plotly->bolides) (1.27.1)
# Requirement already satisfied: ipython>=6.0 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from watermark->bolides) (8.30.0)
# Requirement already satisfied: importlib-metadata>=1.4 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from watermark->bolides) (8.5.0)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from watermark->bolides) (75.6.0)
# Requirement already satisfied: html5lib>=0.999 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from astroquery>=0.3.10->lightkurve->bolides) (1.1)
# Requirement already satisfied: keyring>=15.0 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from astroquery>=0.3.10->lightkurve->bolides) (25.5.0)
# Requirement already satisfied: pyvo>=1.5 in /home/veke6950/.local/lib/python3.11/site-packages (from astroquery>=0.3.10->lightkurve->bolides) (1.6.1)
# Requirement already satisfied: Jinja2>=2.9 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from bokeh>=2.3.2->lightkurve->bolides) (3.1.4)
# Requirement already satisfied: tornado>=6.2 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from bokeh>=2.3.2->lightkurve->bolides) (6.4.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in /home/veke6950/.local/lib/python3.11/site-packages (from bokeh>=2.3.2->lightkurve->bolides) (2025.1.0)
# Requirement already satisfied: zipp>=3.20 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from importlib-metadata>=1.4->watermark->bolides) (3.21.0)
# Requirement already satisfied: decorator in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from ipython>=6.0->watermark->bolides) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from ipython>=6.0->watermark->bolides) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from ipython>=6.0->watermark->bolides) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from ipython>=6.0->watermark->bolides) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from ipython>=6.0->watermark->bolides) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from ipython>=6.0->watermark->bolides) (2.18.0)
# Requirement already satisfied: stack_data in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from ipython>=6.0->watermark->bolides) (0.6.2)
# Requirement already satisfied: traitlets>=5.13.0 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from ipython>=6.0->watermark->bolides) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from ipython>=6.0->watermark->bolides) (4.12.2)
# Requirement already satisfied: autograd in /home/veke6950/.local/lib/python3.11/site-packages (from oktopus>=0.1.2->lightkurve->bolides) (1.7.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->bolides) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from requests>=2.22.0->lightkurve->bolides) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from requests>=2.22.0->lightkurve->bolides) (3.10)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from s3fs>=2024.6.1->lightkurve->bolides) (2.15.2)
# Requirement already satisfied: fsspec==2024.10.0.* in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from s3fs>=2024.6.1->lightkurve->bolides) (2024.10.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from s3fs>=2024.6.1->lightkurve->bolides) (3.11.9)
# Requirement already satisfied: botocore<1.35.37,>=1.35.16 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2024.6.1->lightkurve->bolides) (1.35.36)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2024.6.1->lightkurve->bolides) (1.17.0)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2024.6.1->lightkurve->bolides) (0.12.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2024.6.1->lightkurve->bolides) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2024.6.1->lightkurve->bolides) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2024.6.1->lightkurve->bolides) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2024.6.1->lightkurve->bolides) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2024.6.1->lightkurve->bolides) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2024.6.1->lightkurve->bolides) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2024.6.1->lightkurve->bolides) (1.18.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from html5lib>=0.999->astroquery>=0.3.10->lightkurve->bolides) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.0->watermark->bolides) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from Jinja2>=2.9->bokeh>=2.3.2->lightkurve->bolides) (3.0.2)
# Requirement already satisfied: jaraco.classes in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from keyring>=15.0->astroquery>=0.3.10->lightkurve->bolides) (3.4.0)
# Requirement already satisfied: jaraco.functools in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from keyring>=15.0->astroquery>=0.3.10->lightkurve->bolides) (4.0.0)
# Requirement already satisfied: jaraco.context in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from keyring>=15.0->astroquery>=0.3.10->lightkurve->bolides) (6.0.1)
# Requirement already satisfied: SecretStorage>=3.2 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from keyring>=15.0->astroquery>=0.3.10->lightkurve->bolides) (3.3.3)
# Requirement already satisfied: jeepney>=0.4.2 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from keyring>=15.0->astroquery>=0.3.10->lightkurve->bolides) (0.8.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.0->watermark->bolides) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.0->watermark->bolides) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from stack_data->ipython>=6.0->watermark->bolides) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from stack_data->ipython>=6.0->watermark->bolides) (3.0.0)
# Requirement already satisfied: pure-eval in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from stack_data->ipython>=6.0->watermark->bolides) (0.2.3)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from botocore<1.35.37,>=1.35.16->aiobotocore<3.0.0,>=2.5.4->s3fs>=2024.6.1->lightkurve->bolides) (1.0.1)
# Requirement already satisfied: cryptography>=2.0 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from SecretStorage>=3.2->keyring>=15.0->astroquery>=0.3.10->lightkurve->bolides) (43.0.1)
# Requirement already satisfied: more_itertools in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from jaraco.classes->keyring>=15.0->astroquery>=0.3.10->lightkurve->bolides) (10.5.0)
# Requirement already satisfied: backports.tarfile in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from jaraco.context->keyring>=15.0->astroquery>=0.3.10->lightkurve->bolides) (1.2.0)
# Requirement already satisfied: cffi>=1.12 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from cryptography>=2.0->SecretStorage>=3.2->keyring>=15.0->astroquery>=0.3.10->lightkurve->bolides) (1.17.1)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=2.0->SecretStorage>=3.2->keyring>=15.0->astroquery>=0.3.10->lightkurve->bolides) (2.22)

# %%
bdf = BolideDataFrame(source='glm')
bdf
# Out:
# downloading: 21.8MiB [00:00, 40.7MiB/s]
#                     datetime   longitude   latitude source     detectedBy  \
# 0    2025-04-14 05:27:38.007  -79.653694  37.179504    glm         GLM-19
# 1    2025-04-07 14:44:46.482 -121.083939 -30.575874    glm         GLM-18
# 2    2025-04-07 12:04:21.737  -89.567993  -5.935432    glm  GLM-18,GLM-19
# 3    2025-04-06 16:56:11.333  -76.780445 -21.497066    glm         GLM-19
# 4    2025-04-06 06:50:52.518  -62.247658 -30.919159    glm         GLM-19
# ...                      ...         ...        ...    ...            ...
# 8741 2017-10-08 08:01:06.000  -80.600000  28.100000    glm         GLM-16
# 8742 2017-10-01 12:43:52.000 -111.600000  35.200000    glm         GLM-16
# 8743 2017-09-05 05:11:25.000 -116.900000  49.300000    glm         GLM-16
# 8744 2017-07-31 22:01:34.000 -118.500000  24.700000    glm         GLM-16
# 8745 2017-07-23 06:12:36.000  -69.700000  -6.600000    glm         GLM-16
#
#      confidenceRating lightcurveStructure    energy_g16  energy_g17  \
# 0                high             minimal           NaN         NaN
# 1                 low             minimal           NaN         NaN
# 2              medium                good           NaN         NaN
# 3              medium           very good           NaN         NaN
# 4                 low                good           NaN         NaN
# ...               ...                 ...           ...         ...
# 8741             high                      4.525970e-15         NaN
# 8742             high                      4.525970e-15         NaN
# 8743             high                      7.577910e-15         NaN
# 8744             high                      6.051940e-15         NaN
# 8745             high                      6.051940e-15         NaN
#
#       brightness_g16  ...                                                csv  \
# 0                NaN  ...  [/csv/OR_GLM-L2-LCFA_G19_s20251040527200_e2025...
# 1                NaN  ...  [/csv/OR_GLM-L2-LCFA_G18_s20250971444400_e2025...
# 2                NaN  ...  [/csv/OR_GLM-L2-LCFA_G19_s20250971204200_e2025...
# 3                NaN  ...  [/csv/OR_GLM-L2-LCFA_G19_s20250961656000_e2025...
# 4                NaN  ...  [/csv/OR_GLM-L2-LCFA_G19_s20250960650400_e2025...
# ...              ...  ...                                                ...
# 8741             0.0  ...  [/csv/5d0d404bbceaa433f0426921_OR_GLM-L2-LCFA_...
# 8742             0.0  ...  [/csv/5d0d3ed0bceaa433f0424f20_OR_GLM-L2-LCFA_...
# 8743             0.0  ...  [/csv/5d0d3d7abceaa433f0420916_OR_GLM-L2-LCFA_...
# 8744             0.0  ...  [/csv/5d0d387fbceaa433f04148e7_OR_GLM-L2-LCFA_...
# 8745             0.0  ...  [/csv/5d0d36e9bceaa433f040b258_OR_GLM-L2-LCFA_...
#
#            platform                                       pdfFilenames  \
# 0            GLM-19  [G19_2025-04-14_05h27m38.009_37.180_-79.654_19...
# 1            GLM-18  [G18_2025-04-07_14h44m46.472_-30.576_-121.084_...
# 2     GLM-18,GLM-19  [G19_2025-04-07_12h04m21.736_-5.935_-90.129_19...
# 3            GLM-19  [G19_2025-04-06_16h56m11.312_-21.535_-76.782_1...
# 4            GLM-19  [G19_2025-04-06_06h50m52.528_-30.879_-62.253_1...
# ...             ...                                                ...
# 8741         GLM-16                                                 []
# 8742         GLM-16                                                 []
# 8743         GLM-16                                                 []
# 8744         GLM-16                                                 []
# 8745         GLM-16                                                 []
#
#                           geometry     phase moon_fullness  solarhour  \
# 0        POINT (-79.65369 37.1795)  0.537215      0.925570   0.145977
# 1     POINT (-121.08394 -30.57587)  0.311946      0.623892   6.640348
# 2       POINT (-89.56799 -5.93543)  0.308151      0.616303   6.067350
# 3      POINT (-76.78045 -21.49707)  0.280991      0.561982  11.780056
# 4      POINT (-62.24766 -30.91916)  0.266672      0.533343   2.658274
# ...                            ...       ...           ...        ...
# 8741            POINT (-80.6 28.1)  0.612257      0.775487   2.852754
# 8742           POINT (-111.6 35.2)  0.382178      0.764357   5.464497
# 8743           POINT (-116.9 49.3)  0.490368      0.980735  21.418475
# 8744           POINT (-118.5 24.7)  0.289845      0.579691  14.020207
# 8745            POINT (-69.7 -6.6)  0.994953      0.010095   1.455125
#
#       sun_alt_obs  sun_alt_app             date_retrieved
# 0      -43.275279   -43.275279 2025-05-15 15:19:05.200347
# 1        4.751403     4.584256 2025-05-15 15:19:05.200347
# 2        0.706336     0.271987 2025-05-15 15:19:05.200347
# 3       61.594024    61.585453 2025-05-15 15:19:05.200347
# 4      -45.470506   -45.470506 2025-05-15 15:19:05.200347
# ...           ...          ...                        ...
# 8741   -43.869024   -43.869024 2025-05-15 15:19:05.200347
# 8742    -8.511078    -8.511078 2025-05-15 15:19:05.200347
# 8743   -24.601580   -24.601580 2025-05-15 15:19:05.200347
# 8744    61.079233    61.070477 2025-05-15 15:19:05.200347
# 8745   -64.929766   -64.929766 2025-05-15 15:19:05.200347
#
# [8746 rows x 56 columns]

# %%
## Sorting by confidence! 

highbdf= bdf[bdf.confidenceRating == "high"]
highbdf_16=highbdf.plot_detections(boundary='goes-e', c=np.log(highbdf.energy_g16)) 
highbdf_17=highbdf.plot_detections(boundary='goes-w', c=np.log(highbdf.energy_g17))
plt.show(highbdf_17);
plt.show(highbdf_16);

Enet= (highbdf.energy_g16+highbdf.energy_g17)/2 # using avg
highbdf_Enet=highbdf.plot_detections(boundary= 'goes', c=np.log(Enet), label='Net Energy')
plt.show(highbdf_Enet);

### brightness columns are 0!
### why are g16 and g17 getting such different numbers of high confidence detections?
# Out:
# /opt/anaconda3/envs/current/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/anaconda3/envs/current/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# ### Some Color palette things. Ignore unless you want my plots!

# %%
# !pip install pypalettes
from pypalettes import load_cmap
cmap = load_cmap("BurgYl")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pypalettes in /home/veke6950/.local/lib/python3.11/site-packages (0.1.5)
# Requirement already satisfied: matplotlib>=3.10.0 in /home/veke6950/.local/lib/python3.11/site-packages (from pypalettes) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from matplotlib>=3.10.0->pypalettes) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from matplotlib>=3.10.0->pypalettes) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from matplotlib>=3.10.0->pypalettes) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from matplotlib>=3.10.0->pypalettes) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /home/veke6950/.local/lib/python3.11/site-packages (from matplotlib>=3.10.0->pypalettes) (1.26.3)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from matplotlib>=3.10.0->pypalettes) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from matplotlib>=3.10.0->pypalettes) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from matplotlib>=3.10.0->pypalettes) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from matplotlib>=3.10.0->pypalettes) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/current/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.10.0->pypalettes) (1.17.0)

# %% [markdown]
# #### colors! #FF9898FF, #D9636CFF, #A91E45FF, #691238FF, #251714FF

# %% [markdown]
# ### This has taken up to 45 min to load in the past. Be patient and try not to reload unless you have to!

# %%
bdf.add_website_data()
# Out:
# Downloading data: 100%|██████████| 8746/8746 [44:24<00:00,  3.28it/s]

# %%
# Get lightcurves from bdf!
lightcurves= bdf.lightcurves

# %%
bdf_cleaned = bdf[bdf['rejectedBy'].isna() | (bdf['rejectedBy'] == '')] #what if the 'empty' rejected entries were just strings or NaN? -- test both!  
print(bdf_cleaned.rejectedBy)
# Out:
# 0
# 1
# 2
# 3
# 4
#        ..
# 8741
# 8742
# 8743
# 8744
# 8745
# Name: rejectedBy, Length: 8552, dtype: object

# %% [markdown]
# ### Histogram

# %%
max_fluxes = [] 

for i in range(len(bdf_cleaned.lightcurves)):  # Iterate over each light curve
    fig, ax = plt.subplots()  #ensure each figure is plotted separaetely to get fig data
    
    # Plot the current light curve
    bdf_cleaned.lightcurves.iloc[i].plot(ax=ax)

    # Extract lines from current axis
    lines = ax.get_lines()

    # Extract only the first line's y-data (flux)
    if lines:  # Ensure there's at least one plotted line
        flux_values = lines[0].get_ydata()
        max_flux = np.max(flux_values)  
        max_fluxes.append(max_flux)
    else:
        print(f"No flux data found for light curve {i}")

    plt.close('all')  # Close all figures to prevent overload

#print(max_fluxes)

# %% [markdown]
# ### Histogram Midpoints (peak bolide brightnesses avg over bins)

# %%
 
    
    fig, ax = plt.subplots()
    ax.plot([1, 2, 3], [4, 5, 6])
    
    fig.patch.set_facecolor('lightgray')
    fig.patch.set_alpha(0.5)            # Figure transparency
    ax.set_facecolor('whitesmoke')
    ax.patch.set_alpha(0.7)              # Plot area transparency
    
    plt.show()

# %%
#histogram of peak fluxes (UNFILTERED)
counts, bins, _= plt.hist(max_fluxes, bins=50, color='#D9636CFF') #prob won't need patches, use bins to get midpoint, counts = instances/bin
plt.title('Histogram of Peak Brightness Values')
plt.yscale('log')  # Log scale for better visualization
plt.xlabel('Peak Brightness')
plt.ylabel('Frequency')
#plt.savefig("Histogram_PeakBrightnessValues.png") ---> save as figure, sometimes doesn't work for some reason

mids= (bins[:-1] + bins[1:]) / 2
df = pd.DataFrame({'midpoints': mids, 'counts': counts})
df.to_csv("Midpoints.txt", index=False)

Midpoints = pd.read_csv("Midpoints.txt", delimiter=',')

midpoints_x = Midpoints['midpoints']
midpoints_y = Midpoints['counts']

nonzero_mask = midpoints_y != 0

filtered_counts = midpoints_y[nonzero_mask]
filtered_midpoints = midpoints_x[nonzero_mask]

nonzero_mask = counts != 0

filtered_counts = midpoints_y[nonzero_mask]
filtered_midpoints = midpoints_x[nonzero_mask]

plt.plot(filtered_midpoints, filtered_counts, marker='o', linestyle='-', lw=0.5, color='#691238FF')

plt.yscale('log')
plt.xlabel('Peak Brightness')
plt.ylabel('Frequency')
plt.title('Peak Brightness Histogram with Midpoints')
#plt.grid(True, color='#FF9898FF')
plt.show();

# %% [markdown]
# ### Histogram (but this time with pretty colors and dark bg)

# %%
# Generate histogram data
counts, bins = np.histogram(max_fluxes, bins=50)
mids = (bins[:-1] + bins[1:]) / 2

# Filter non-zero bins
nonzero_mask = counts != 0
filtered_counts = counts[nonzero_mask]
filtered_mids = mids[nonzero_mask]

# Plot
fig, ax = plt.subplots(figsize=(10, 6), facecolor='black')
ax.set_facecolor('black')

# Set fixed color
fixed_color = '#D9636CFF'
bar_width = np.diff(bins).mean()

# Draw fixed-color bars
for x, y in zip(filtered_mids, filtered_counts):
    ax.bar(x, y, width=bar_width, color=fixed_color, edgecolor=fixed_color, alpha=0.9)

# Optional: overlay midpoint line
#ax.plot(filtered_mids, filtered_counts,
        #marker='o', linestyle='-', lw=0.5,
        #color='white', label='Midpoint Line')

# Style
ax.set_yscale('log')
ax.set_xlabel('Peak Brightness',color='#F5BA98FF', fontsize=15)
ax.set_ylabel('Frequency', color='#F5BA98FF', fontsize=15)
ax.set_title('Peak Brightness Histogram', color='#F5BA98FF', fontsize=25)
ax.tick_params(colors='white')
#ax.grid(True, color='white', linestyle='--', linewidth=0.3, alpha=0.4)

# Legend
#legend = ax.legend(facecolor='black', edgecolor='white')
#plt.setp(legend.get_texts(), color='white')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Aligning Data:

# %%
#pull where midpoints fall on blue line (1) and (2) midpoints compare (1),(2), using chisq

yflash=filtered_counts
xflash= filtered_midpoints
yerr=np.sqrt(np.asarray(yflash))


ysfd = np.loadtxt('impact_earth.dat')
ysfd_x = ysfd[:, 0]  # Original x values
ysfd_y = ysfd[:, 1]  # Original ysfd values


#plotting: 

plt.figure(figsize=(10, 6))

plt.errorbar(xflash, yflash, yerr, marker='*', color='#D9636CFF', linestyle='None', label='Histogram Midpts')

plt.xscale('linear')
plt.yscale('log')

plt.xlabel('Peak Brightness')
plt.ylabel('Frequency')
plt.legend();
plt.show();

# %% [markdown]
# ### Power law SFD

# %% [markdown]
# use power law slope below (-1) for power law fit
#
# ![image.png](attachment:a5d93018-d408-474e-86d8-dbe8d6fbc9d7.png)

# %%
def powerlaw(x,a,b):
  return a*x**b

fudgefactor=50 #manually altered to get it to fit 

## VK: this only affects the y intercept, not the slope (which we need for chi squared)
 #values from MH SFD (above image) 
A=0.05718482777133716
xsfd=np.linspace(0.1,5,1000)
ysfd=powerlaw(np.asarray(xsfd),A*fudgefactor,-3.4533697696073387)

# %% [markdown]
# ### Histogram midpoints + SFD curve attempt 1 -- check scale?

# %%
plt.figure(figsize=(10, 6))



plt.errorbar(xflash, yflash, yerr, marker='*', color='#A91E45FF', linestyle='None', label='Histogram Midpts')
plt.plot(xsfd, ysfd, '-', label='SFD', color='mediumvioletred')

plt.xscale('linear')
plt.yscale('log')

plt.xlabel('Peak Brightness')
plt.ylabel('Frequency')
plt.legend();
plt.show();

# %%
plt.figure(figsize=(10, 6))
fig, ax1 = plt.subplots()

#Bottom X-axis = Histogram Data
errbar = ax1.errorbar(xflash, yflash, yerr,marker='x', color='#A91E45FF',linestyle='None', label='Histogram Midpts')
ax1.set_xlabel('Peak Brightness')
ax1.set_ylabel('Frequency')
ax1.tick_params(axis='x', colors='#A91E45FF')
ax1.xaxis.label.set_color('#A91E45FF')

#Top X-axis: SFD

#making a second x axis on the top that shares the same y axis
ax2 = ax1.twiny()


line2, = ax2.plot(xsfd, ysfd,linestyle='-', label='SFD',color='#D9636CFF')
ax2.set_xlabel('Impactor Radius (km)')
ax2.tick_params(axis='x', colors='#D9636CFF')
ax2.xaxis.label.set_color('#D9636CFF')

#Merge Legends
handles1, labels1 = ax1.get_legend_handles_labels()
handles2, labels2 = ax2.get_legend_handles_labels()
all_handles = handles1 + [line2]
all_labels = labels1 + [labels2[0]]

#Legend
legend = ax1.legend(all_handles, all_labels, loc='upper right', frameon=True, framealpha=0.85, fontsize=10)
legend.get_texts()[0].set_color('#A91E45FF')  # Histogram Midpts
legend.get_texts()[1].set_color('#D9636CFF')  # SFD

ax1.spines['top'].set_visible(False)     # Hide ax1's top spine (since ax2 is there)
ax2.spines['bottom'].set_visible(False)  # Hide ax2's bottom spine (since ax1 is there)
plt.yscale('symlog')#VK: symmetric log about 0 (negatives included)
plt.tight_layout()

plt.show()

# %% [markdown]
# ### Fully formatted SFD + Histogram Midpoints Plot

# %%
fig, ax1 = plt.subplots(figsize=(10, 6), facecolor='black')
ax1.set_facecolor('black')

# Plot histogram midpoints
errbar = ax1.errorbar(
    xflash, yflash, yerr,
    marker='x', linestyle='None',
    color='#FF6487',  # brighter magenta-red
    label='Histogram Midpts',
    elinewidth=1.0, capsize=2, markersize=6
)

# Y-axis and lower x-axis
ax1.set_xlabel('Peak Brightness', color='#F5BA98FF', fontsize=12)
ax1.set_ylabel('Frequency', color='#F5BA98FF', fontsize=12)
ax1.tick_params(axis='x', colors='white', labelsize=11)
ax1.tick_params(axis='y', colors='white', labelsize=11)
ax1.yaxis.label.set_color('#F5BA98FF')
ax1.xaxis.label.set_color('#F5BA98FF')

# Top x-axis for SFD
ax2 = ax1.twiny()
line2, = ax2.plot(xsfd, ysfd, linestyle='-', linewidth=2,
                  color='#FFC0CB', label='SFD', alpha=0.85)  # light pink for contrast

ax2.set_xlabel('Impactor Radius (km)', color='#F5BA98FF', fontsize=12)
ax2.tick_params(axis='x', colors='white', labelsize=11)
ax2.xaxis.label.set_color('#F5BA98FF')

# Merge legends
handles1, labels1 = ax1.get_legend_handles_labels()
handles2, labels2 = ax2.get_legend_handles_labels()
all_handles = handles1 + [line2]
all_labels = labels1 + [labels2[0]]

legend = ax1.legend(
    all_handles, all_labels,
    loc='upper right',
    frameon=True,
    facecolor='black',
    edgecolor='white',
    framealpha=0.9,
    fontsize=11
)
legend.get_texts()[0].set_color('#FF6487')
legend.get_texts()[1].set_color('#FFC0CB')

# spine formatting
for spine in ax1.spines.values():
    spine.set_color('white')
for spine in ax2.spines.values():
    spine.set_color('white')
ax1.spines['top'].set_visible(False)
ax2.spines['bottom'].set_visible(False)
ax1.set_yscale('symlog')

# Grid (if you want it)
ax1.grid(True, color='gray', linestyle='--', linewidth=0.4, alpha=0.5)

plt.tight_layout()
plt.title("Fireball Peak Brightness/Radii vs NEO SFD Powerlaw Fit",color='#F5BA98FF', fontsize=25)
fig.savefig("histogram_vs_sfd_dark_styled.png", dpi=300, facecolor='black')

plt.show()

# %% [markdown]
# ### Corresponding Midpoint values --> SFD curve (also an initial Chisq)

# %%
from scipy.interpolate import interp1d

xsfd=np.linspace(0.1,5,1000)
ysfd=powerlaw(np.asarray(xsfd),A*fudgefactor,-3.4533697696073387)

Xcorrs= pd.read_csv("corresponding xpoints.csv", delimiter=',')
xXcorrs = Xcorrs.iloc[:, 0]
yXcorrs = Xcorrs.iloc[:, 1]
#compare yXcorrs to ysfd (at xXcorrs) for chi squared

print(f"len(xsfd): {len(xsfd)}")
print(f"len(ysfd): {len(ysfd)}")


# Interpolate ysfd to the xXcorrs points
interp_func = interp1d(xsfd, ysfd, bounds_error=False, fill_value=0)
ysfd_interp = interp_func(xXcorrs)

# Avoid division by zero in chi-squared
mask = ysfd_interp > 0
chi_squared = np.sum(((yXcorrs[mask] - ysfd_interp[mask])**2) / ysfd_interp[mask])

print("Chi-squared:", chi_squared)
# Out:
# len(xsfd): 1000
# len(ysfd): 1000
# Chi-squared: 5144.494063774444

# %% [markdown]
# ### Chi-Squared pt.2 (very very high)

# %%
CHI2 = 0
for yf, yf_model, ye in zip(yflash, ysfd_interp, yerr): 
    step = (yf - yf_model)**2 / (ye + 1e-49)**2  
    CHI2 += step

print(f"Chi-squared: {CHI2}")
# Out:
# Chi-squared: 16906362.016197305

# %% [markdown]
# ### Reduced Chi Squared and P-value (+ fully formatted tail-only fit)

# %%
#import curvefit for tail fit
from scipy.optimize import curve_fit


plt.style.use('dark_background')  # Apply dark background globally

def powerlaw(x, a, b):
    return a * x**b

# Tail cutoff
tail_cutoff = 0.5e-12
tail_mask = xXcorrs > tail_cutoff

x_tail = xXcorrs[tail_mask]
y_tail = yXcorrs[tail_mask]

# Clean tail data
valid_tail_mask = (x_tail > 0) & (y_tail > 0)
x_fit = x_tail[valid_tail_mask]
y_fit = y_tail[valid_tail_mask]

# Power-law fit
popt, pcov = curve_fit(powerlaw, x_fit, y_fit, p0=[1, -3])
a_fit, b_fit = popt
print(f"Fitted power-law (tail only): a = {a_fit:.3e}, b = {b_fit:.3f}")

# Interpolation for chi-squared
interp_func = interp1d(xsfd, ysfd, bounds_error=False, fill_value=0)
ysfd_interp = interp_func(x_tail)

valid_chi_mask = ysfd_interp > 0
chi_squared_tail = np.sum(
    ((y_tail[valid_chi_mask] - ysfd_interp[valid_chi_mask])**2) / ysfd_interp[valid_chi_mask]
)
reduced_chi_squared = chi_squared_tail / np.sum(valid_chi_mask)

print(f"Tail-only chi-squared: {chi_squared_tail:.2f}")
print(f"Tail data points used: {np.sum(valid_chi_mask)}")
print(f"Reduced chi-squared: {reduced_chi_squared:.2f}")


fig, ax = plt.subplots(figsize=(10, 6), facecolor='black')
ax.set_facecolor('black')

# Tail data
ax.errorbar(
    x_tail, y_tail, yerr=np.sqrt(y_tail),
    fmt='x', color='#FF6487', label='Tail Data',
    elinewidth=1.0, capsize=2, markersize=6
)

# SFD fit
line_fit, = ax.plot(xsfd, ysfd, linestyle='-', linewidth=2,
                    color='#FFC0CB', label='Power-law Fit (Tail)', alpha=0.85)


ax.set_xlabel('Peak Brightness', color='#F5BA98FF', fontsize=12)
ax.set_ylabel('Frequency', color='#F5BA98FF', fontsize=12)
ax.tick_params(axis='x', colors='white', labelsize=11)
ax.tick_params(axis='y', colors='white', labelsize=11)
ax.yaxis.label.set_color('#F5BA98FF')
ax.xaxis.label.set_color('#F5BA98FF')
ax.set_yscale('log')


ax.grid(True, color='gray', linestyle='--', linewidth=0.4, alpha=0.5)
for spine in ax.spines.values():
    spine.set_color('white')


legend = ax.legend(
    loc='upper right',
    frameon=True,
    facecolor='black',
    edgecolor='white',
    framealpha=0.9,
    fontsize=11
)
legend.get_texts()[0].set_color('#FFC0CB')  # Tail Data
legend.get_texts()[1].set_color('#FF6487')  # SFD line

plt.title('Tail-Only Power-law Fit', color='#F5BA98FF', fontsize=20)
plt.tight_layout()
plt.show()
# Out:
# Fitted power-law (tail only): a = 2.346e+00, b = -2.654
# Tail-only chi-squared: 5144.49
# Tail data points used: 26
# Reduced chi-squared: 197.87

# %%
#regular version of my tail fit 
from scipy.optimize import curve_fit

tail_cutoff = 0.5e-12  # Adjust(?) -- I wanted a value smaller than the tick size for the lower x axis
tail_mask = xXcorrs > tail_cutoff

x_tail = xXcorrs[tail_mask]
y_tail = yXcorrs[tail_mask]

#remove zeros to avoid log(0) or division errors -- thanks chat
valid_tail_mask = (x_tail > 0) & (y_tail > 0)
x_fit = x_tail[valid_tail_mask]
y_fit = y_tail[valid_tail_mask]

#fitting the tail 
popt, pcov = curve_fit(powerlaw, x_fit, y_fit, p0=[1, -3])
a_fit, b_fit = popt
print(f"Fitted power-law (tail only): a = {a_fit:.3e}, b = {b_fit:.3f}")


#interpolate model at tail x-points for chi-squ
interp_func = interp1d(xsfd, ysfd, bounds_error=False, fill_value=0)
ysfd_interp = interp_func(x_tail)

#tail chi sq.
valid_chi_mask = ysfd_interp > 0
chi_squared_tail = np.sum(
    ((y_tail[valid_chi_mask] - ysfd_interp[valid_chi_mask])**2) / ysfd_interp[valid_chi_mask]
)

print(f"Tail-only chi-squared: {chi_squared_tail:.2f}")
print(f"Tail data points used: {np.sum(valid_chi_mask)}")
print(f"Reduced chi-squared: {chi_squared_tail / np.sum(valid_chi_mask):.2f}")

plt.figure(figsize=(8, 6))
plt.plot(xsfd, ysfd, 'r-', label='Power-law Fit (Tail)')
plt.errorbar(x_tail, y_tail, yerr=np.sqrt(y_tail), fmt='x', color='#251714FF', label='Tail Data')
plt.yscale('log')
plt.xlabel('Peak Brightness')
plt.ylabel('Frequency')
plt.title('Tail-Only Power-law Fit')
plt.grid(True, which='both') #formatting to make it look good
plt.legend()
plt.tight_layout()
plt.show()

 ### Colors (again): #FF9898FF, #A91E45FF, #D9636CFF, #251714FF
# Out:
# Fitted power-law (tail only): a = 2.346e+00, b = -2.654
# Tail-only chi-squared: 5144.49
# Tail data points used: 26
# Reduced chi-squared: 197.87

# %% [markdown]
# ### Tail values for Red. Chisq. and P-value

# %%
dof=50-2 #lost 2 dof because our model has 2 parameters ---> dof= #bins(50) - power law params (2)
print('(net)reduced chi2 =',round(CHI2/dof,2))

#for p value:
from scipy.stats import chi2

# 26 points used, 2 fit parameters → 24 dof
dof = np.sum(valid_chi_mask) - 2
p_value = 1 - chi2.cdf(chi_squared_tail, dof) 

print(f"(tail) p-value: {p_value:.4e}")
# Out:
# (net)reduced chi2 = 352215.88
# (tail) p-value: 0.0000e+00

# %% [markdown]
# ### Fully Formatted Global Detections GOES-W (log Energy scale)

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from matplotlib.patches import Circle
import datetime
from pypalettes import load_cmap
import numpy as np

# Setup
cmap = load_cmap("BurgYl")
bdf['log_energy'] = np.log(bdf.energy_g17)  # Or whichever column contains GOES-West energy

# Create GOES-West globe view
fig = plt.figure(figsize=(12, 10), facecolor='black')
proj = ccrs.Geostationary(central_longitude=180)
ax = plt.axes(projection=proj)
ax.set_global()
ax.set_facecolor('black')
ax.coastlines(color='white', linewidth=1.2)

# Plot GLM detections
sc = ax.scatter(
    bdf['longitude'],
    bdf['latitude'],
    c=bdf['log_energy'],
    cmap=cmap,
    s=5,
    transform=ccrs.PlateCarree(),
    alpha=0.85,
    zorder=9
)

# Colorbar
cbar = plt.colorbar(sc, ax=ax, orientation='vertical', shrink=0.6, pad=0.03)
cbar.set_label('log(Energy)', color='white')
cbar.ax.tick_params(color='white')
plt.setp(cbar.ax.yaxis.get_ticklabels(), color='white')

# Title
plt.title("GLM Detections\n(GOES-West View, log Energy)", color='#FFC8A2', fontsize=25, pad=20)

# Globe circle overlay
circle = Circle((0.5, 0.5), 0.495,
                transform=ax.transAxes,
                edgecolor='white',
                facecolor='none',
                linewidth=1.5,
                zorder=10)
ax.set_position([0.05, 0.05, 0.9, 0.9])
ax.add_patch(circle)

plt.tight_layout()
plt.show()
# Out:
# /opt/anaconda3/envs/current/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# ### Fully Formatted Global Detections GOES-E (log Energy scale)

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from matplotlib.patches import Circle
import datetime
from pypalettes import load_cmap
import numpy as np

# Setup
cmap = load_cmap("BurgYl")
bdf['log_energy'] = np.log(bdf.energy_g16)  # Or whichever column contains GOES-East energy

# Create GOES-West globe view
fig = plt.figure(figsize=(12, 10), facecolor='black')
proj = ccrs.Geostationary(central_longitude=180)
ax.set_global()
ax.set_facecolor('black')
ax.coastlines(color='white', linewidth=1.2)

# Plot GLM detections
sc = ax.scatter(
    bdf['longitude'],
    bdf['latitude'],
    c=bdf['log_energy'],
    cmap=cmap,
    s=5,
    transform=ccrs.PlateCarree(),
    alpha=0.85,
    zorder=9
)

# Colorbar
cbar = plt.colorbar(sc, ax=ax, orientation='vertical', shrink=0.6, pad=0.03)
cbar.set_label('log(Energy)', color='white')
cbar.ax.tick_params(color='white')
plt.setp(cbar.ax.yaxis.get_ticklabels(), color='white')

# Title
plt.title("GLM Detections\n(GOES-West View, log Energy)", color='#FFC8A2', fontsize=16, pad=20)

# Globe circle overlay
circle = Circle((0.5, 0.5), 0.495,
                transform=ax.transAxes,
                edgecolor='white',
                facecolor='none',
                linewidth=1.5,
                zorder=10)
ax.set_position([0.05, 0.05, 0.9, 0.9])
ax.add_patch(circle)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_4163390/942771848.py:32: UserWarning: Adding colorbar to a different Figure <Figure size 1200x1000 with 3 Axes> than <Figure size 1200x1000 with 0 Axes> which fig.colorbar is called on.
#   cbar = plt.colorbar(sc, ax=ax, orientation='vertical', shrink=0.6, pad=0.03)

# %% [markdown]
# #### EXTRA: workarounds and notes

# %%
### For accessing lightcurves through bdf (a big problem for the start of this project) 

lc_csv_paths= bdf['csv'] #filepaths from the 'csv' column in bdf.csv --- may need to use _id instead(?)


# get csv column within the bolide dataframe to downloaded + access lightcurves (?)
lightcurves_list = []
for file_path in lc_csv_paths:
    lightcurve = pd.read_csv(file_path).download()
    #flux=lightcurve.flux # no attributes of flux or time
    #time=lightcurve.time
    lightcurves_list.append(lightcurve[0]) 
    
#### ERROR: can't directly access files whose paths are in the 'csv' column but this is the general idea of trying to extract lc data from csv.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 9
#       7 lightcurves_list = []
#       8 for file_path in lc_csv_paths:
# ----> 9     lightcurve = pd.read_csv(file_path).download()
#      10     #flux=lightcurve.flux # no attributes of flux or time
#      11     #time=lightcurve.time
#      12     lightcurves_list.append(lightcurve[0])
#
# File /opt/anaconda3/envs/current/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /opt/anaconda3/envs/current/lib/python3.11/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /opt/anaconda3/envs/current/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /opt/anaconda3/envs/current/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1895, in TextFileReader._make_engine(self, f, engine)
#    1893 elif engine != "python":
#    1894     msg = f"Invalid file path or buffer object type: {type(f)}"
# -> 1895     raise ValueError(msg)
#    1897 try:
#    1898     return mapping[engine](f, **self.options)
#
# ValueError: Invalid file path or buffer object type: <class 'list'>
