# %% [markdown]
# ### The Beginning: Install Packages

# %% [markdown]
# !pip install watermark
# %reload_ext autoreload
# %autoreload 2
# !pip install --upgrade numpy==1.26.3
# %load_ext watermark

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Get dataframe (bdf) --> Make sure you know what kinds of data is here and how to use it via Github's tutorial file

# %%
# !pip install bolides
from bolides import BolideDataFrame;
# Out:
# Requirement already satisfied: bolides in c:\users\under\anaconda3\lib\site-packages (0.6.0)
# Requirement already satisfied: tqdm in c:\users\under\anaconda3\lib\site-packages (from bolides) (4.66.4)
# Requirement already satisfied: numpy in c:\users\under\anaconda3\lib\site-packages (from bolides) (1.26.4)
# Requirement already satisfied: pandas in c:\users\under\anaconda3\lib\site-packages (from bolides) (2.2.2)
# Requirement already satisfied: ephem in c:\users\under\anaconda3\lib\site-packages (from bolides) (4.2)
# Requirement already satisfied: geopandas in c:\users\under\anaconda3\lib\site-packages (from bolides) (1.1.0)
# Requirement already satisfied: matplotlib in c:\users\under\anaconda3\lib\site-packages (from bolides) (3.10.0)
# Requirement already satisfied: lightkurve in c:\users\under\anaconda3\lib\site-packages (from bolides) (2.5.1)
# Requirement already satisfied: netCDF4 in c:\users\under\anaconda3\lib\site-packages (from bolides) (1.7.2)
# Requirement already satisfied: pyproj in c:\users\under\anaconda3\lib\site-packages (from bolides) (3.7.1)
# Requirement already satisfied: astropy in c:\users\under\anaconda3\lib\site-packages (from bolides) (6.1.0)
# Requirement already satisfied: simplekml in c:\users\under\anaconda3\lib\site-packages (from bolides) (1.3.6)
# Requirement already satisfied: scikit-learn in c:\users\under\anaconda3\lib\site-packages (from bolides) (1.4.2)
# Requirement already satisfied: watermark in c:\users\under\anaconda3\lib\site-packages (from bolides) (2.5.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\under\anaconda3\lib\site-packages (from bolides) (4.12.3)
# Requirement already satisfied: plotly in c:\users\under\anaconda3\lib\site-packages (from bolides) (5.22.0)
# Requirement already satisfied: pyerfa>=2.0.1.1 in c:\users\under\anaconda3\lib\site-packages (from astropy->bolides) (2.0.1.4)
# Requirement already satisfied: astropy-iers-data>=0.2024.4.29.0.28.48 in c:\users\under\anaconda3\lib\site-packages (from astropy->bolides) (0.2024.6.3.0.31.14)
# Requirement already satisfied: PyYAML>=3.13 in c:\users\under\anaconda3\lib\site-packages (from astropy->bolides) (6.0.1)
# Requirement already satisfied: packaging>=19.0 in c:\users\under\anaconda3\lib\site-packages (from astropy->bolides) (23.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\under\anaconda3\lib\site-packages (from beautifulsoup4->bolides) (2.5)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\under\anaconda3\lib\site-packages (from geopandas->bolides) (0.11.0)
# Requirement already satisfied: shapely>=2.0.0 in c:\users\under\anaconda3\lib\site-packages (from geopandas->bolides) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\under\anaconda3\lib\site-packages (from pandas->bolides) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\under\anaconda3\lib\site-packages (from pandas->bolides) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\under\anaconda3\lib\site-packages (from pandas->bolides) (2023.3)
# Requirement already satisfied: certifi in c:\users\under\anaconda3\lib\site-packages (from pyproj->bolides) (2025.4.26)
# Requirement already satisfied: astroquery>=0.3.10 in c:\users\under\anaconda3\lib\site-packages (from lightkurve->bolides) (0.4.10)
# Requirement already satisfied: bokeh>=2.3.2 in c:\users\under\anaconda3\lib\site-packages (from lightkurve->bolides) (3.4.1)
# Requirement already satisfied: fbpca>=1.0 in c:\users\under\anaconda3\lib\site-packages (from lightkurve->bolides) (1.0)
# Requirement already satisfied: memoization>=0.3.1 in c:\users\under\anaconda3\lib\site-packages (from lightkurve->bolides) (0.4.0)
# Requirement already satisfied: patsy>=0.5.0 in c:\users\under\anaconda3\lib\site-packages (from lightkurve->bolides) (0.5.6)
# Requirement already satisfied: requests>=2.22.0 in c:\users\under\anaconda3\lib\site-packages (from lightkurve->bolides) (2.32.2)
# Requirement already satisfied: s3fs>=2024.6.1 in c:\users\under\anaconda3\lib\site-packages (from lightkurve->bolides) (2025.5.1)
# Requirement already satisfied: scipy>=1.7 in c:\users\under\anaconda3\lib\site-packages (from lightkurve->bolides) (1.13.1)
# Requirement already satisfied: uncertainties>=3.1.4 in c:\users\under\anaconda3\lib\site-packages (from lightkurve->bolides) (3.2.3)
# Requirement already satisfied: urllib3>=1.23 in c:\users\under\anaconda3\lib\site-packages (from lightkurve->bolides) (2.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\under\anaconda3\lib\site-packages (from matplotlib->bolides) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\under\anaconda3\lib\site-packages (from matplotlib->bolides) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\under\anaconda3\lib\site-packages (from matplotlib->bolides) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\under\anaconda3\lib\site-packages (from matplotlib->bolides) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\users\under\anaconda3\lib\site-packages (from matplotlib->bolides) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\under\anaconda3\lib\site-packages (from matplotlib->bolides) (3.0.9)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\under\anaconda3\lib\site-packages (from scikit-learn->bolides) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\under\anaconda3\lib\site-packages (from scikit-learn->bolides) (2.2.0)
# Requirement already satisfied: colorama in c:\users\under\anaconda3\lib\site-packages (from tqdm->bolides) (0.4.6)
# Requirement already satisfied: cftime in c:\users\under\anaconda3\lib\site-packages (from netCDF4->bolides) (1.6.4.post1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\under\anaconda3\lib\site-packages (from plotly->bolides) (8.2.2)
# Requirement already satisfied: ipython>=6.0 in c:\users\under\anaconda3\lib\site-packages (from watermark->bolides) (8.25.0)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\under\anaconda3\lib\site-packages (from watermark->bolides) (7.0.1)
# Requirement already satisfied: setuptools in c:\users\under\anaconda3\lib\site-packages (from watermark->bolides) (69.5.1)
# Requirement already satisfied: html5lib>=0.999 in c:\users\under\anaconda3\lib\site-packages (from astroquery>=0.3.10->lightkurve->bolides) (1.1)
# Requirement already satisfied: keyring>=15.0 in c:\users\under\anaconda3\lib\site-packages (from astroquery>=0.3.10->lightkurve->bolides) (24.3.1)
# Requirement already satisfied: pyvo>=1.5 in c:\users\under\anaconda3\lib\site-packages (from astroquery>=0.3.10->lightkurve->bolides) (1.7)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\under\anaconda3\lib\site-packages (from bokeh>=2.3.2->lightkurve->bolides) (3.1.4)
# Requirement already satisfied: tornado>=6.2 in c:\users\under\anaconda3\lib\site-packages (from bokeh>=2.3.2->lightkurve->bolides) (6.4.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\under\anaconda3\lib\site-packages (from bokeh>=2.3.2->lightkurve->bolides) (2022.9.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\under\anaconda3\lib\site-packages (from importlib-metadata>=1.4->watermark->bolides) (3.17.0)
# Requirement already satisfied: decorator in c:\users\under\anaconda3\lib\site-packages (from ipython>=6.0->watermark->bolides) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\under\anaconda3\lib\site-packages (from ipython>=6.0->watermark->bolides) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\under\anaconda3\lib\site-packages (from ipython>=6.0->watermark->bolides) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\under\anaconda3\lib\site-packages (from ipython>=6.0->watermark->bolides) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\under\anaconda3\lib\site-packages (from ipython>=6.0->watermark->bolides) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\under\anaconda3\lib\site-packages (from ipython>=6.0->watermark->bolides) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\under\anaconda3\lib\site-packages (from ipython>=6.0->watermark->bolides) (5.14.3)
# Requirement already satisfied: six in c:\users\under\anaconda3\lib\site-packages (from patsy>=0.5.0->lightkurve->bolides) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\under\anaconda3\lib\site-packages (from requests>=2.22.0->lightkurve->bolides) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\under\anaconda3\lib\site-packages (from requests>=2.22.0->lightkurve->bolides) (3.7)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in c:\users\under\anaconda3\lib\site-packages (from s3fs>=2024.6.1->lightkurve->bolides) (2.12.3)
# Requirement already satisfied: fsspec==2025.5.1 in c:\users\under\anaconda3\lib\site-packages (from s3fs>=2024.6.1->lightkurve->bolides) (2025.5.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\under\anaconda3\lib\site-packages (from s3fs>=2024.6.1->lightkurve->bolides) (3.9.5)
# Requirement already satisfied: botocore<1.34.70,>=1.34.41 in c:\users\under\anaconda3\lib\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2024.6.1->lightkurve->bolides) (1.34.69)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in c:\users\under\anaconda3\lib\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2024.6.1->lightkurve->bolides) (1.14.1)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in c:\users\under\anaconda3\lib\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2024.6.1->lightkurve->bolides) (0.7.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\under\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2024.6.1->lightkurve->bolides) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\under\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2024.6.1->lightkurve->bolides) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\under\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2024.6.1->lightkurve->bolides) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\under\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2024.6.1->lightkurve->bolides) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\under\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2024.6.1->lightkurve->bolides) (1.9.3)
# Requirement already satisfied: webencodings in c:\users\under\anaconda3\lib\site-packages (from html5lib>=0.999->astroquery>=0.3.10->lightkurve->bolides) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\under\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=6.0->watermark->bolides) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\under\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh>=2.3.2->lightkurve->bolides) (2.1.3)
# Requirement already satisfied: jaraco.classes in c:\users\under\anaconda3\lib\site-packages (from keyring>=15.0->astroquery>=0.3.10->lightkurve->bolides) (3.2.1)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in c:\users\under\anaconda3\lib\site-packages (from keyring>=15.0->astroquery>=0.3.10->lightkurve->bolides) (0.2.2)
# Requirement already satisfied: wcwidth in c:\users\under\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.0->watermark->bolides) (0.2.5)
# Requirement already satisfied: executing in c:\users\under\anaconda3\lib\site-packages (from stack-data->ipython>=6.0->watermark->bolides) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\under\anaconda3\lib\site-packages (from stack-data->ipython>=6.0->watermark->bolides) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\under\anaconda3\lib\site-packages (from stack-data->ipython>=6.0->watermark->bolides) (0.2.2)
# Requirement already satisfied: typing_extensions>=3.7 in c:\users\under\anaconda3\lib\site-packages (from aioitertools<1.0.0,>=0.5.1->aiobotocore<3.0.0,>=2.5.4->s3fs>=2024.6.1->lightkurve->bolides) (4.11.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\under\anaconda3\lib\site-packages (from botocore<1.34.70,>=1.34.41->aiobotocore<3.0.0,>=2.5.4->s3fs>=2024.6.1->lightkurve->bolides) (1.0.1)
# Requirement already satisfied: more-itertools in c:\users\under\anaconda3\lib\site-packages (from jaraco.classes->keyring>=15.0->astroquery>=0.3.10->lightkurve->bolides) (10.1.0)
# C:\Users\under\anaconda3\Lib\site-packages\lightkurve\prf\__init__.py:7: UserWarning: Warning: the tpfmodel submodule is not available without oktopus installed, which requires a current version of autograd. See #1452 for details.
#   warnings.warn(

# %%
bdf = BolideDataFrame(source='glm')
bdf
# Out:
# downloading: 22.7MiB [00:04, 5.05MiB/s]
#                              datetime   longitude   latitude source  \
# 0    2025-06-20 20:18:58.875000+00:00 -112.922256  -8.272419    glm
# 1    2025-06-20 17:33:06.317000+00:00 -168.461510 -37.292299    glm
# 2    2025-06-20 13:48:15.181000+00:00 -160.275452  20.025345    glm
# 3    2025-06-20 12:34:32.739000+00:00 -128.397560  33.464287    glm
# 4    2025-06-20 11:01:40.075000+00:00 -125.260246 -13.025614    glm
# ...                               ...         ...        ...    ...
# 9124        2017-10-08 08:01:06+00:00  -80.600000  28.100000    glm
# 9125        2017-10-01 12:43:52+00:00 -111.600000  35.200000    glm
# 9126        2017-09-05 05:11:25+00:00 -116.900000  49.300000    glm
# 9127        2017-07-31 22:01:34+00:00 -118.500000  24.700000    glm
# 9128        2017-07-23 06:12:36+00:00  -69.700000  -6.600000    glm
#
#      detectedBy confidenceRating lightcurveStructure  peak_energy_g16  \
# 0        GLM-18           medium                good              NaN
# 1        GLM-18              low                good              NaN
# 2        GLM-18              low             minimal              NaN
# 3        GLM-18           medium                good              NaN
# 4        GLM-18           medium                good              NaN
# ...         ...              ...                 ...              ...
# 9124     GLM-16             high                                  0.0
# 9125     GLM-16             high                                  0.0
# 9126     GLM-16             high                                  0.0
# 9127     GLM-16             high                                  0.0
# 9128     GLM-16             high                                  0.0
#
#       peak_energy_g17  peak_energy_g18  ...  \
# 0                 NaN              0.0  ...
# 1                 NaN              0.0  ...
# 2                 NaN              0.0  ...
# 3                 NaN              0.0  ...
# 4                 NaN              0.0  ...
# ...               ...              ...  ...
# 9124              NaN              NaN  ...
# 9125              NaN              NaN  ...
# 9126              NaN              NaN  ...
# 9127              NaN              NaN  ...
# 9128              NaN              NaN  ...
#
#                                                     csv platform  \
# 0     [/csv/OR_GLM-L2-LCFA_G18_s20251712018400_e2025...   GLM-18
# 1     [/csv/OR_GLM-L2-LCFA_G18_s20251711733000_e2025...   GLM-18
# 2     [/csv/OR_GLM-L2-LCFA_G18_s20251711348000_e2025...   GLM-18
# 3     [/csv/OR_GLM-L2-LCFA_G18_s20251711234200_e2025...   GLM-18
# 4     [/csv/OR_GLM-L2-LCFA_G18_s20251711101400_e2025...   GLM-18
# ...                                                 ...      ...
# 9124  [/csv/5d0d404bbceaa433f0426921_OR_GLM-L2-LCFA_...   GLM-16
# 9125  [/csv/5d0d3ed0bceaa433f0424f20_OR_GLM-L2-LCFA_...   GLM-16
# 9126  [/csv/5d0d3d7abceaa433f0420916_OR_GLM-L2-LCFA_...   GLM-16
# 9127  [/csv/5d0d387fbceaa433f04148e7_OR_GLM-L2-LCFA_...   GLM-16
# 9128  [/csv/5d0d36e9bceaa433f040b258_OR_GLM-L2-LCFA_...   GLM-16
#
#                                            pdfFilenames  \
# 0     [G18_2025-06-20_20h18m58.875_-8.272_-112.961_1...
# 1     [G18_2025-06-20_17h33m06.323_-37.325_-168.473_...
# 2     [G18_2025-06-20_13h48m15.181_20.025_-160.275_1...
# 3     [G18_2025-06-20_12h34m32.742_33.464_-128.399_1...
# 4     [G18_2025-06-20_11h01m40.050_-12.988_-125.299_...
# ...                                                 ...
# 9124                                                 []
# 9125                                                 []
# 9126                                                 []
# 9127                                                 []
# 9128                                                 []
#
#                           geometry     phase moon_fullness  solarhour  \
# 0      POINT (-112.92226 -8.27242)  0.843339      0.313323  12.759668
# 1      POINT (-168.46151 -37.2923)  0.839409      0.321182   6.292664
# 2      POINT (-160.27545 20.02534)  0.834082      0.331836   3.091482
# 3      POINT (-128.39756 33.46429)  0.832336      0.335329   3.988381
# 4     POINT (-125.26025 -13.02561)  0.830135      0.339730   2.649848
# ...                            ...       ...           ...        ...
# 9124            POINT (-80.6 28.1)  0.612257      0.775487   2.852754
# 9125           POINT (-111.6 35.2)  0.382178      0.764357   5.464497
# 9126           POINT (-116.9 49.3)  0.490368      0.980735  21.418475
# 9127           POINT (-118.5 24.7)  0.289845      0.579691  14.020207
# 9128            POINT (-69.7 -6.6)  0.994953      0.010095   1.455125
#
#       sun_alt_obs  sun_alt_app             date_retrieved
# 0       56.398641    56.388109 2025-07-01 10:48:50.847605
# 1      -10.668599   -10.668599 2025-07-01 10:48:50.847605
# 2      -27.295634   -27.295634 2025-07-01 10:48:50.847605
# 3       -9.520976    -9.520976 2025-07-01 10:48:50.847605
# 4      -50.980204   -50.980204 2025-07-01 10:48:50.847605
# ...           ...          ...                        ...
# 9124   -43.869024   -43.869024 2025-07-01 10:48:50.847605
# 9125    -8.511078    -8.511078 2025-07-01 10:48:50.847605
# 9126   -24.601580   -24.601580 2025-07-01 10:48:50.847605
# 9127    61.079233    61.070477 2025-07-01 10:48:50.847605
# 9128   -64.929766   -64.929766 2025-07-01 10:48:50.847605
#
# [9129 rows x 56 columns]

# %%
highbdf.plot_detections(boundary='goes-w')
plt.show()

# %%
## Sorting by confidence! 

highbdf= bdf[bdf.confidenceRating == "high"] #only bolides whose confidence ratings are high
highbdf_16=highbdf.plot_detections(boundary='goes-e') #high confidence bolides from GOES 16 #c=np.log(highbdf.peak_energy_g16
highbdf_17=highbdf.plot_detections(boundary='goes-w')
plt.show(highbdf_16); plt.show(highbdf_17)

Enet= (highbdf.peak_energy_g16+highbdf.peak_energy_g17)/2 # using avg
highbdf_Enet=highbdf.plot_detections(boundary= 'goes', label='Net Energy') #, c=np.log(Enet)
plt.show(highbdf_Enet);

### brightness columns are 0!
### why are g16 and g17 getting such different numbers of high confidence detections?

# %% [markdown]
# ### Some Color palette things. Ignore unless you want my plots!

# %%
# !pip install pypalettes
from pypalettes import load_cmap
cmap = load_cmap("BurgYl")
# Out:
# Collecting pypalettes
#   Downloading pypalettes-0.1.6-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: matplotlib>=3.10.0 in c:\users\under\anaconda3\lib\site-packages (from pypalettes) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\under\anaconda3\lib\site-packages (from matplotlib>=3.10.0->pypalettes) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\under\anaconda3\lib\site-packages (from matplotlib>=3.10.0->pypalettes) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\under\anaconda3\lib\site-packages (from matplotlib>=3.10.0->pypalettes) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\under\anaconda3\lib\site-packages (from matplotlib>=3.10.0->pypalettes) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\under\anaconda3\lib\site-packages (from matplotlib>=3.10.0->pypalettes) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\under\anaconda3\lib\site-packages (from matplotlib>=3.10.0->pypalettes) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\under\anaconda3\lib\site-packages (from matplotlib>=3.10.0->pypalettes) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\under\anaconda3\lib\site-packages (from matplotlib>=3.10.0->pypalettes) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\under\anaconda3\lib\site-packages (from matplotlib>=3.10.0->pypalettes) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\under\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.10.0->pypalettes) (1.16.0)
# Downloading pypalettes-0.1.6-py3-none-any.whl (366 kB)
#    ---------------------------------------- 0.0/366.2 kB ? eta -:--:--
#    ---- ---------------------------------- 41.0/366.2 kB 991.0 kB/s eta 0:00:01
#    ---- ---------------------------------- 41.0/366.2 kB 991.0 kB/s eta 0:00:01
#    ---- ---------------------------------- 41.0/366.2 kB 991.0 kB/s eta 0:00:01
#    ------- ------------------------------- 71.7/366.2 kB 326.8 kB/s eta 0:00:01
#    --------- ----------------------------- 92.2/366.2 kB 435.7 kB/s eta 0:00:01
#    ------------------- ------------------ 184.3/366.2 kB 619.5 kB/s eta 0:00:01
#    --------------------- ---------------- 204.8/366.2 kB 621.6 kB/s eta 0:00:01
#    -------------------------------------- 366.2/366.2 kB 949.3 kB/s eta 0:00:00
# Installing collected packages: pypalettes
# Successfully installed pypalettes-0.1.6

# %% [markdown]
# #### colors! #FF9898FF, #D9636CFF, #A91E45FF, #691238FF, #251714FF

# %% [markdown]
# ### This has taken up to 45 min to load in the past. Be patient and try not to reload unless you have to!

# %%
bdf.add_website_data()
# Out:
# Downloading data:   0%|          | 5/9129 [00:02<1:22:49,  1.84it/s]
# C:\Users\under\anaconda3\Lib\site-packages\executing\executing.py:713: DeprecationWarning: ast.Str is deprecated and will be removed in Python 3.14; use ast.Constant instead
#   right=ast.Str(s=sentinel),
# C:\Users\under\anaconda3\Lib\ast.py:587: DeprecationWarning: Attribute s is deprecated and will be removed in Python 3.14; use value instead
#   return Constant(*args, **kwargs)
# C:\Users\under\anaconda3\Lib\site-packages\executing\executing.py:713: DeprecationWarning: ast.Str is deprecated and will be removed in Python 3.14; use ast.Constant instead
#   right=ast.Str(s=sentinel),
# C:\Users\under\anaconda3\Lib\ast.py:587: DeprecationWarning: Attribute s is deprecated and will be removed in Python 3.14; use value instead
#   return Constant(*args, **kwargs)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 bdf.add_website_data()
#
# File ~\anaconda3\Lib\site-packages\bolides\bdf.py:813, in BolideDataFrame.add_website_data(self, ids)
#     811 # get the data from the website by passing the ids
#     812 from .sources import glm_website_event
# --> 813 data = glm_website_event(ids)
#     815 # initialize empty columns in the BolideDataFrame
#     816 cols = data.keys()
#
# File ~\anaconda3\Lib\site-packages\bolides\sources.py:273, in glm_website_event(ids)
#     270 geodata = attachment['geoData']
#     272 # since there is data for this satellite, set to zero if nan
# --> 273 if integrated_energies[platform.lower()] is np.nan:
#     274     integrated_energies[platform.lower()] = 0
#     276 # obtain flux from the geodata, and sum it up to get
#     277 # integrated energy
#
# KeyError: 'g19'

# %%
# Get lightcurves from bdf!
lightcurves= bdf.lightcurves
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13644\1817494916.py in ?()
#       1 # Get lightcurves from bdf!
# ----> 2 lightcurves= bdf.lightcurves
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'BolideDataFrame' object has no attribute 'lightcurves'

# %%
bdf_cleaned = bdf[bdf['rejectedBy'].isna() | (bdf['rejectedBy'] == '')] #what if the 'empty' rejected entries were just strings or NaN? -- test both!  
print(bdf_cleaned.rejectedBy)

# %% [markdown]
# ### Histogram

# %%
max_fluxes = [] 

for i in range(len(bdf_cleaned.lightcurves)):  # Iterate over each light curve
    fig, ax = plt.subplots()  #ensure each figure is plotted separaetely to get fig data
    
    # Plot the current light curve
    bdf_cleaned.lightcurves.iloc[i].plot(ax=ax)

    # Extract lines from current axis
    lines = ax.get_lines()

    # Extract only the first line's y-data (flux)
    if lines:  # Ensure there's at least one plotted line
        flux_values = lines[0].get_ydata()
        max_flux = np.max(flux_values)  
        max_fluxes.append(max_flux)
    else:
        print(f"No flux data found for light curve {i}")

    plt.close('all')  # Close all figures to prevent overload

#print(max_fluxes)

# %% [markdown]
# ### Histogram Midpoints (peak bolide brightnesses avg over bins)

# %%
 
    
    fig, ax = plt.subplots()
    ax.plot([1, 2, 3], [4, 5, 6])
    
    fig.patch.set_facecolor('lightgray')
    fig.patch.set_alpha(0.5)            # Figure transparency
    ax.set_facecolor('whitesmoke')
    ax.patch.set_alpha(0.7)              # Plot area transparency
    
    plt.show()

# %%
#histogram of peak fluxes (UNFILTERED)
counts, bins, _= plt.hist(max_fluxes, bins=50, color='#D9636CFF') #prob won't need patches, use bins to get midpoint, counts = instances/bin
plt.title('Histogram of Peak Brightness Values')
plt.yscale('log')  # Log scale for better visualization
plt.xlabel('Peak Brightness')
plt.ylabel('Frequency')
#plt.savefig("Histogram_PeakBrightnessValues.png") ---> save as figure, sometimes doesn't work for some reason

mids= (bins[:-1] + bins[1:]) / 2
df = pd.DataFrame({'midpoints': mids, 'counts': counts})
df.to_csv("Midpoints.txt", index=False)

Midpoints = pd.read_csv("Midpoints.txt", delimiter=',')

midpoints_x = Midpoints['midpoints']
midpoints_y = Midpoints['counts']

nonzero_mask = midpoints_y != 0

filtered_counts = midpoints_y[nonzero_mask]
filtered_midpoints = midpoints_x[nonzero_mask]

nonzero_mask = counts != 0

filtered_counts = midpoints_y[nonzero_mask]
filtered_midpoints = midpoints_x[nonzero_mask]

plt.plot(filtered_midpoints, filtered_counts, marker='o', linestyle='-', lw=0.5, color='#691238FF')

plt.yscale('log')
plt.xlabel('Peak Brightness')
plt.ylabel('Frequency')
plt.title('Peak Brightness Histogram with Midpoints')
#plt.grid(True, color='#FF9898FF')
plt.show();

# %% [markdown]
# ### Histogram (but this time with pretty colors and dark bg)

# %%
# Generate histogram data
counts, bins = np.histogram(max_fluxes, bins=50)
mids = (bins[:-1] + bins[1:]) / 2

# Filter non-zero bins
nonzero_mask = counts != 0
filtered_counts = counts[nonzero_mask]
filtered_mids = mids[nonzero_mask]

# Plot
fig, ax = plt.subplots(figsize=(10, 6), facecolor='black')
ax.set_facecolor('black')

# Set fixed color
fixed_color = '#D9636CFF'
bar_width = np.diff(bins).mean()

# Draw fixed-color bars
for x, y in zip(filtered_mids, filtered_counts):
    ax.bar(x, y, width=bar_width, color=fixed_color, edgecolor=fixed_color, alpha=0.9)

# Optional: overlay midpoint line
#ax.plot(filtered_mids, filtered_counts,
        #marker='o', linestyle='-', lw=0.5,
        #color='white', label='Midpoint Line')

# Style
ax.set_yscale('log')
ax.set_xlabel('Peak Brightness',color='#F5BA98FF', fontsize=15)
ax.set_ylabel('Frequency', color='#F5BA98FF', fontsize=15)
ax.set_title('Peak Brightness Histogram', color='#F5BA98FF', fontsize=25)
ax.tick_params(colors='white')
#ax.grid(True, color='white', linestyle='--', linewidth=0.3, alpha=0.4)

# Legend
#legend = ax.legend(facecolor='black', edgecolor='white')
#plt.setp(legend.get_texts(), color='white')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Aligning Data:

# %%
#pull where midpoints fall on blue line (1) and (2) midpoints compare (1),(2), using chisq

yflash=filtered_counts
xflash= filtered_midpoints
yerr=np.sqrt(np.asarray(yflash))


ysfd = np.loadtxt('impact_earth.dat')
ysfd_x = ysfd[:, 0]  # Original x values
ysfd_y = ysfd[:, 1]  # Original ysfd values


#plotting: 

plt.figure(figsize=(10, 6))

plt.errorbar(xflash, yflash, yerr, marker='*', color='#D9636CFF', linestyle='None', label='Histogram Midpts')

plt.xscale('linear')
plt.yscale('log')

plt.xlabel('Peak Brightness')
plt.ylabel('Frequency')
plt.legend();
plt.show();

# %% [markdown]
# ### Power law SFD

# %% [markdown]
# use power law slope below (-1) for power law fit
#
# ![image.png](attachment:a5d93018-d408-474e-86d8-dbe8d6fbc9d7.png)

# %%
def powerlaw(x,a,b):
  return a*x**b

fudgefactor=50 #manually altered to get it to fit 

## VK: this only affects the y intercept, not the slope (which we need for chi squared)
 #values from MH SFD (above image) 
A=0.05718482777133716
xsfd=np.linspace(0.1,5,1000)
ysfd=powerlaw(np.asarray(xsfd),A*fudgefactor,-3.4533697696073387)

# %% [markdown]
# ### Histogram midpoints + SFD curve attempt 1 -- check scale?

# %%
plt.figure(figsize=(10, 6))



plt.errorbar(xflash, yflash, yerr, marker='*', color='#A91E45FF', linestyle='None', label='Histogram Midpts')
plt.plot(xsfd, ysfd, '-', label='SFD', color='mediumvioletred')

plt.xscale('linear')
plt.yscale('log')

plt.xlabel('Peak Brightness')
plt.ylabel('Frequency')
plt.legend();
plt.show();

# %%
plt.figure(figsize=(10, 6))
fig, ax1 = plt.subplots()

#Bottom X-axis = Histogram Data
errbar = ax1.errorbar(xflash, yflash, yerr,marker='x', color='#A91E45FF',linestyle='None', label='Histogram Midpts')
ax1.set_xlabel('Peak Brightness')
ax1.set_ylabel('Frequency')
ax1.tick_params(axis='x', colors='#A91E45FF')
ax1.xaxis.label.set_color('#A91E45FF')

#Top X-axis: SFD

#making a second x axis on the top that shares the same y axis
ax2 = ax1.twiny()


line2, = ax2.plot(xsfd, ysfd,linestyle='-', label='SFD',color='#D9636CFF')
ax2.set_xlabel('Impactor Radius (km)')
ax2.tick_params(axis='x', colors='#D9636CFF')
ax2.xaxis.label.set_color('#D9636CFF')

#Merge Legends
handles1, labels1 = ax1.get_legend_handles_labels()
handles2, labels2 = ax2.get_legend_handles_labels()
all_handles = handles1 + [line2]
all_labels = labels1 + [labels2[0]]

#Legend
legend = ax1.legend(all_handles, all_labels, loc='upper right', frameon=True, framealpha=0.85, fontsize=10)
legend.get_texts()[0].set_color('#A91E45FF')  # Histogram Midpts
legend.get_texts()[1].set_color('#D9636CFF')  # SFD

ax1.spines['top'].set_visible(False)     # Hide ax1's top spine (since ax2 is there)
ax2.spines['bottom'].set_visible(False)  # Hide ax2's bottom spine (since ax1 is there)
plt.yscale('symlog')#VK: symmetric log about 0 (negatives included)
plt.tight_layout()

plt.show()

# %% [markdown]
# ### Fully formatted SFD + Histogram Midpoints Plot

# %%
fig, ax1 = plt.subplots(figsize=(10, 6), facecolor='black')
ax1.set_facecolor('black')

# Plot histogram midpoints
errbar = ax1.errorbar(
    xflash, yflash, yerr,
    marker='x', linestyle='None',
    color='#FF6487',  # brighter magenta-red
    label='Histogram Midpts',
    elinewidth=1.0, capsize=2, markersize=6
)

# Y-axis and lower x-axis
ax1.set_xlabel('Peak Brightness', color='#F5BA98FF', fontsize=12)
ax1.set_ylabel('Frequency', color='#F5BA98FF', fontsize=12)
ax1.tick_params(axis='x', colors='white', labelsize=11)
ax1.tick_params(axis='y', colors='white', labelsize=11)
ax1.yaxis.label.set_color('#F5BA98FF')
ax1.xaxis.label.set_color('#F5BA98FF')

# Top x-axis for SFD
ax2 = ax1.twiny()
line2, = ax2.plot(xsfd, ysfd, linestyle='-', linewidth=2,
                  color='#FFC0CB', label='SFD', alpha=0.85)  # light pink for contrast

ax2.set_xlabel('Impactor Radius (km)', color='#F5BA98FF', fontsize=12)
ax2.tick_params(axis='x', colors='white', labelsize=11)
ax2.xaxis.label.set_color('#F5BA98FF')

# Merge legends
handles1, labels1 = ax1.get_legend_handles_labels()
handles2, labels2 = ax2.get_legend_handles_labels()
all_handles = handles1 + [line2]
all_labels = labels1 + [labels2[0]]

legend = ax1.legend(
    all_handles, all_labels,
    loc='upper right',
    frameon=True,
    facecolor='black',
    edgecolor='white',
    framealpha=0.9,
    fontsize=11
)
legend.get_texts()[0].set_color('#FF6487')
legend.get_texts()[1].set_color('#FFC0CB')

# spine formatting
for spine in ax1.spines.values():
    spine.set_color('white')
for spine in ax2.spines.values():
    spine.set_color('white')
ax1.spines['top'].set_visible(False)
ax2.spines['bottom'].set_visible(False)
ax1.set_yscale('symlog')

# Grid (if you want it)
ax1.grid(True, color='gray', linestyle='--', linewidth=0.4, alpha=0.5)

plt.tight_layout()
plt.title("Fireball Peak Brightness/Radii vs NEO SFD Powerlaw Fit",color='#F5BA98FF', fontsize=25)
fig.savefig("histogram_vs_sfd_dark_styled.png", dpi=300, facecolor='black')

plt.show()

# %% [markdown]
# ### Corresponding Midpoint values --> SFD curve (also an initial Chisq)

# %%
from scipy.interpolate import interp1d

xsfd=np.linspace(0.1,5,1000)
ysfd=powerlaw(np.asarray(xsfd),A*fudgefactor,-3.4533697696073387)

Xcorrs= pd.read_csv("corresponding xpoints.csv", delimiter=',')
xXcorrs = Xcorrs.iloc[:, 0]
yXcorrs = Xcorrs.iloc[:, 1]
#compare yXcorrs to ysfd (at xXcorrs) for chi squared

print(f"len(xsfd): {len(xsfd)}")
print(f"len(ysfd): {len(ysfd)}")


# Interpolate ysfd to the xXcorrs points
interp_func = interp1d(xsfd, ysfd, bounds_error=False, fill_value=0)
ysfd_interp = interp_func(xXcorrs)

# Avoid division by zero in chi-squared
mask = ysfd_interp > 0
chi_squared = np.sum(((yXcorrs[mask] - ysfd_interp[mask])**2) / ysfd_interp[mask])

print("Chi-squared:", chi_squared)

# %% [markdown]
# ### Chi-Squared pt.2 (very very high)

# %%
CHI2 = 0
for yf, yf_model, ye in zip(yflash, ysfd_interp, yerr): 
    step = (yf - yf_model)**2 / (ye + 1e-49)**2  
    CHI2 += step

print(f"Chi-squared: {CHI2}")

# %% [markdown]
# ### Reduced Chi Squared and P-value (+ fully formatted tail-only fit)

# %%
#import curvefit for tail fit
from scipy.optimize import curve_fit


plt.style.use('dark_background')  # Apply dark background globally

def powerlaw(x, a, b):
    return a * x**b

# Tail cutoff
tail_cutoff = 0.5e-12
tail_mask = xXcorrs > tail_cutoff

x_tail = xXcorrs[tail_mask]
y_tail = yXcorrs[tail_mask]

# Clean tail data
valid_tail_mask = (x_tail > 0) & (y_tail > 0)
x_fit = x_tail[valid_tail_mask]
y_fit = y_tail[valid_tail_mask]

# Power-law fit
popt, pcov = curve_fit(powerlaw, x_fit, y_fit, p0=[1, -3])
a_fit, b_fit = popt
print(f"Fitted power-law (tail only): a = {a_fit:.3e}, b = {b_fit:.3f}")

# Interpolation for chi-squared
interp_func = interp1d(xsfd, ysfd, bounds_error=False, fill_value=0)
ysfd_interp = interp_func(x_tail)

valid_chi_mask = ysfd_interp > 0
chi_squared_tail = np.sum(
    ((y_tail[valid_chi_mask] - ysfd_interp[valid_chi_mask])**2) / ysfd_interp[valid_chi_mask]
)
reduced_chi_squared = chi_squared_tail / np.sum(valid_chi_mask)

print(f"Tail-only chi-squared: {chi_squared_tail:.2f}")
print(f"Tail data points used: {np.sum(valid_chi_mask)}")
print(f"Reduced chi-squared: {reduced_chi_squared:.2f}")


fig, ax = plt.subplots(figsize=(10, 6), facecolor='black')
ax.set_facecolor('black')

# Tail data
ax.errorbar(
    x_tail, y_tail, yerr=np.sqrt(y_tail),
    fmt='x', color='#FF6487', label='Tail Data',
    elinewidth=1.0, capsize=2, markersize=6
)

# SFD fit
line_fit, = ax.plot(xsfd, ysfd, linestyle='-', linewidth=2,
                    color='#FFC0CB', label='Power-law Fit (Tail)', alpha=0.85)


ax.set_xlabel('Peak Brightness', color='#F5BA98FF', fontsize=12)
ax.set_ylabel('Frequency', color='#F5BA98FF', fontsize=12)
ax.tick_params(axis='x', colors='white', labelsize=11)
ax.tick_params(axis='y', colors='white', labelsize=11)
ax.yaxis.label.set_color('#F5BA98FF')
ax.xaxis.label.set_color('#F5BA98FF')
ax.set_yscale('log')


ax.grid(True, color='gray', linestyle='--', linewidth=0.4, alpha=0.5)
for spine in ax.spines.values():
    spine.set_color('white')


legend = ax.legend(
    loc='upper right',
    frameon=True,
    facecolor='black',
    edgecolor='white',
    framealpha=0.9,
    fontsize=11
)
legend.get_texts()[0].set_color('#FFC0CB')  # Tail Data
legend.get_texts()[1].set_color('#FF6487')  # SFD line

plt.title('Tail-Only Power-law Fit', color='#F5BA98FF', fontsize=20)
plt.tight_layout()
plt.show()

# %%
#regular version of my tail fit 
from scipy.optimize import curve_fit

tail_cutoff = 0.5e-12  # Adjust(?) -- I wanted a value smaller than the tick size for the lower x axis
tail_mask = xXcorrs > tail_cutoff

x_tail = xXcorrs[tail_mask]
y_tail = yXcorrs[tail_mask]

#remove zeros to avoid log(0) or division errors -- thanks chat
valid_tail_mask = (x_tail > 0) & (y_tail > 0)
x_fit = x_tail[valid_tail_mask]
y_fit = y_tail[valid_tail_mask]

#fitting the tail 
popt, pcov = curve_fit(powerlaw, x_fit, y_fit, p0=[1, -3])
a_fit, b_fit = popt
print(f"Fitted power-law (tail only): a = {a_fit:.3e}, b = {b_fit:.3f}")


#interpolate model at tail x-points for chi-squ
interp_func = interp1d(xsfd, ysfd, bounds_error=False, fill_value=0)
ysfd_interp = interp_func(x_tail)

#tail chi sq.
valid_chi_mask = ysfd_interp > 0
chi_squared_tail = np.sum(
    ((y_tail[valid_chi_mask] - ysfd_interp[valid_chi_mask])**2) / ysfd_interp[valid_chi_mask]
)

print(f"Tail-only chi-squared: {chi_squared_tail:.2f}")
print(f"Tail data points used: {np.sum(valid_chi_mask)}")
print(f"Reduced chi-squared: {chi_squared_tail / np.sum(valid_chi_mask):.2f}")

plt.figure(figsize=(8, 6))
plt.plot(xsfd, ysfd, 'r-', label='Power-law Fit (Tail)')
plt.errorbar(x_tail, y_tail, yerr=np.sqrt(y_tail), fmt='x', color='#251714FF', label='Tail Data')
plt.yscale('log')
plt.xlabel('Peak Brightness')
plt.ylabel('Frequency')
plt.title('Tail-Only Power-law Fit')
plt.grid(True, which='both') #formatting to make it look good
plt.legend()
plt.tight_layout()
plt.show()

 ### Colors (again): #FF9898FF, #A91E45FF, #D9636CFF, #251714FF

# %% [markdown]
# ### Tail values for Red. Chisq. and P-value

# %%
dof=50-2 #lost 2 dof because our model has 2 parameters ---> dof= #bins(50) - power law params (2)
print('(net)reduced chi2 =',round(CHI2/dof,2))

#for p value:
from scipy.stats import chi2

# 26 points used, 2 fit parameters → 24 dof
dof = np.sum(valid_chi_mask) - 2
p_value = 1 - chi2.cdf(chi_squared_tail, dof) 

print(f"(tail) p-value: {p_value:.4e}")

# %% [markdown]
# ### Fully Formatted Global Detections GOES-W (log Energy scale)

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from matplotlib.patches import Circle
import datetime
from pypalettes import load_cmap
import numpy as np

# Setup
cmap = load_cmap("BurgYl")
bdf['log_energy'] = np.log(bdf.energy_g17)  # Or whichever column contains GOES-West energy

# Create GOES-West globe view
fig = plt.figure(figsize=(12, 10), facecolor='black')
proj = ccrs.Geostationary(central_longitude=180)
ax = plt.axes(projection=proj)
ax.set_global()
ax.set_facecolor('black')
ax.coastlines(color='white', linewidth=1.2)

# Plot GLM detections
sc = ax.scatter(
    bdf['longitude'],
    bdf['latitude'],
    c=bdf['log_energy'],
    cmap=cmap,
    s=5,
    transform=ccrs.PlateCarree(),
    alpha=0.85,
    zorder=9
)

# Colorbar
cbar = plt.colorbar(sc, ax=ax, orientation='vertical', shrink=0.6, pad=0.03)
cbar.set_label('log(Energy)', color='white')
cbar.ax.tick_params(color='white')
plt.setp(cbar.ax.yaxis.get_ticklabels(), color='white')

# Title
plt.title("GLM Detections\n(GOES-West View, log Energy)", color='#FFC8A2', fontsize=25, pad=20)

# Globe circle overlay
circle = Circle((0.5, 0.5), 0.495,
                transform=ax.transAxes,
                edgecolor='white',
                facecolor='none',
                linewidth=1.5,
                zorder=10)
ax.set_position([0.05, 0.05, 0.9, 0.9])
ax.add_patch(circle)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Fully Formatted Global Detections GOES-E (log Energy scale)

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from matplotlib.patches import Circle
import datetime
from pypalettes import load_cmap
import numpy as np

# Setup
cmap = load_cmap("BurgYl")
bdf['log_energy'] = np.log(bdf.energy_g16)  # Or whichever column contains GOES-East energy

# Create GOES-West globe view
fig = plt.figure(figsize=(12, 10), facecolor='black')
proj = ccrs.Geostationary(central_longitude=180)
ax.set_global()
ax.set_facecolor('black')
ax.coastlines(color='white', linewidth=1.2)

# Plot GLM detections
sc = ax.scatter(
    bdf['longitude'],
    bdf['latitude'],
    c=bdf['log_energy'],
    cmap=cmap,
    s=5,
    transform=ccrs.PlateCarree(),
    alpha=0.85,
    zorder=9
)

# Colorbar
cbar = plt.colorbar(sc, ax=ax, orientation='vertical', shrink=0.6, pad=0.03)
cbar.set_label('log(Energy)', color='white')
cbar.ax.tick_params(color='white')
plt.setp(cbar.ax.yaxis.get_ticklabels(), color='white')

# Title
plt.title("GLM Detections\n(GOES-West View, log Energy)", color='#FFC8A2', fontsize=16, pad=20)

# Globe circle overlay
circle = Circle((0.5, 0.5), 0.495,
                transform=ax.transAxes,
                edgecolor='white',
                facecolor='none',
                linewidth=1.5,
                zorder=10)
ax.set_position([0.05, 0.05, 0.9, 0.9])
ax.add_patch(circle)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### EXTRA: workarounds and notes

# %%
### For accessing lightcurves through bdf (a big problem for the start of this project) 

lc_csv_paths= bdf['csv'] #filepaths from the 'csv' column in bdf.csv --- may need to use _id instead(?)


# get csv column within the bolide dataframe to downloaded + access lightcurves (?)
lightcurves_list = []
for file_path in lc_csv_paths:
    lightcurve = pd.read_csv(file_path).download()
    #flux=lightcurve.flux # no attributes of flux or time
    #time=lightcurve.time
    lightcurves_list.append(lightcurve[0]) 
    
#### ERROR: can't directly access files whose paths are in the 'csv' column but this is the general idea of trying to extract lc data from csv.
