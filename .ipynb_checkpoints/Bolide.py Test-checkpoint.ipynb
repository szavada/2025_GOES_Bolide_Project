# %%
import Bolide
b=Bolide.Bolide

# %%
b.airrho(8)
# Out:
# 1.2238476012139081

# %%
b.radii('datafixed_bolide_data.csv', [12, 15], "g16")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 b.radii('datafixed_bolide_data.csv', [12, 15], "g16")
#
# File ~\Documents\GitHub\GOES_Bolide_Project\Bolide.py:69, in Bolide.radii(dataframe, index, satellite)
#      66 totalerror= 0
#      68 for u in range (imaxenergy): #until the bolide catastrophically destructs...
# ---> 69     deltalatlong = np.abs(degtom(lat[u], long[u], lat[u+1], long[u+1]))[0] #calculate the distance in meters for each step in latitude/longitude
#      71     errordeltalatlong= degtom(lat[u], long[u], lat[u+1], long[u+1])[1]
#      73     deltaalt = np.abs(alt[u+1]-alt[u]) #the change in altitude for each step
#
# NameError: name 'degtom' is not defined
