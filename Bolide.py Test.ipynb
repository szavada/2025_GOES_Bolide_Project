# %%
from Bolide import Bolide
b= Bolide('datafixed_bolide_data.csv', [12, 15], "g16")

# %%
b

# %%
b.airrho(8)
# Out:
# 1.2238476012139081

# %%
b.radii()
# Out:
#    Index in datafixed_bolide_data.csv Satellite  Rocky Bolide Radii  \
# 0                                  12       g16            0.003861
#
#    Rocky Bolide Uncertainty  Metal Bolide Radii  Metal Bolide Uncertainty  \
# 0                  5.373393            0.001802                  2.507584
#
#    Icy Bolide Radii  Icy Bolide Uncertainty
# 0          0.018017               25.075835
