# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from bolides import BolideDataFrame;
# Out:
# C:\Users\under\anaconda3\Lib\site-packages\lightkurve\prf\__init__.py:7: UserWarning: Warning: the tpfmodel submodule is not available without oktopus installed, which requires a current version of autograd. See #1452 for details.
#   warnings.warn(

# %%
bdf = BolideDataFrame(source='glm')
bdf
# Out:
# downloading: 22.9MiB [00:00, 38.8MiB/s]
#                              datetime   longitude   latitude source  \
# 0    2025-07-14 12:22:41.754000+00:00  -94.593380   0.520992    glm
# 1    2025-07-14 01:33:30.717000+00:00  -42.630569  12.523827    glm
# 2    2025-07-13 17:48:37.901000+00:00 -130.898445 -25.096497    glm
# 3    2025-07-13 16:12:03.841000+00:00 -149.085129 -28.651236    glm
# 4    2025-07-13 14:06:30.650000+00:00 -102.902710  -1.465599    glm
# ...                               ...         ...        ...    ...
# 9228        2017-10-08 08:01:06+00:00  -80.600000  28.100000    glm
# 9229        2017-10-01 12:43:52+00:00 -111.600000  35.200000    glm
# 9230        2017-09-05 05:11:25+00:00 -116.900000  49.300000    glm
# 9231        2017-07-31 22:01:34+00:00 -118.500000  24.700000    glm
# 9232        2017-07-23 06:12:36+00:00  -69.700000  -6.600000    glm
#
#          detectedBy confidenceRating lightcurveStructure  peak_energy_g17  \
# 0     GLM-18,GLM-19             auto                                  NaN
# 1            GLM-19             auto                                  NaN
# 2     GLM-18,GLM-19           medium                good              NaN
# 3            GLM-18             auto                                  NaN
# 4            GLM-19             auto                                  NaN
# ...             ...              ...                 ...              ...
# 9228         GLM-16             high                                  NaN
# 9229         GLM-16             high                                  NaN
# 9230         GLM-16             high                                  NaN
# 9231         GLM-16             high                                  NaN
# 9232         GLM-16             high                                  NaN
#
#       peak_energy_g18  peak_energy_g19  ...       platform  \
# 0                 0.0              0.0  ...  GLM-18,GLM-19
# 1                 NaN              0.0  ...         GLM-19
# 2                 0.0              0.0  ...  GLM-18,GLM-19
# 3                 0.0              NaN  ...         GLM-18
# 4                 NaN              0.0  ...         GLM-19
# ...               ...              ...  ...            ...
# 9228              NaN              NaN  ...         GLM-16
# 9229              NaN              NaN  ...         GLM-16
# 9230              NaN              NaN  ...         GLM-16
# 9231              NaN              NaN  ...         GLM-16
# 9232              NaN              NaN  ...         GLM-16
#
#                                            pdfFilenames peak_energy_g16  \
# 0     [G19_2025-07-14_12h22m41.755_0.515_-95.157_192...             NaN
# 1     [G19_2025-07-14_01h33m30.720_12.557_-42.625_19...             NaN
# 2     [G19_2025-07-13_17h48m37.947_-25.111_-131.585_...             NaN
# 3     [G18_2025-07-13_16h12m03.820_-28.651_-149.128_...             NaN
# 4     [G19_2025-07-13_14h06m30.651_-1.466_-102.903_1...             NaN
# ...                                                 ...             ...
# 9228                                                 []             0.0
# 9229                                                 []             0.0
# 9230                                                 []             0.0
# 9231                                                 []             0.0
# 9232                                                 []             0.0
#
#                           geometry     phase moon_fullness  solarhour  \
# 0        POINT (-94.59338 0.52099)  0.649750      0.700500   5.973013
# 1       POINT (-42.63057 12.52383)  0.634396      0.731209  22.618506
# 2      POINT (-130.89845 -25.0965)  0.623400      0.753200   8.986386
# 3     POINT (-149.08513 -28.65124)  0.621116      0.757768   6.164554
# 4       POINT (-102.90271 -1.4656)  0.618147      0.763707   7.151000
# ...                            ...       ...           ...        ...
# 9228            POINT (-80.6 28.1)  0.612257      0.775487   2.852754
# 9229           POINT (-111.6 35.2)  0.382178      0.764357   5.464497
# 9230           POINT (-116.9 49.3)  0.490368      0.980735  21.418475
# 9231           POINT (-118.5 24.7)  0.289845      0.579691  14.020207
# 9232            POINT (-69.7 -6.6)  0.994953      0.010095   1.455125
#
#      sun_alt_obs  sun_alt_app             date_retrieved
# 0       0.313041    -0.184685 2025-07-30 11:01:51.588639
# 1     -50.225287   -50.225287 2025-07-30 11:01:51.588639
# 2      25.876689    25.844012 2025-07-30 11:01:51.588639
# 3      -8.181375    -8.181908 2025-07-30 11:01:51.588639
# 4      15.491830    15.434648 2025-07-30 11:01:51.588639
# ...          ...          ...                        ...
# 9228  -43.869024   -43.869024 2025-07-30 11:01:51.588639
# 9229   -8.511078    -8.511078 2025-07-30 11:01:51.588639
# 9230  -24.601580   -24.601580 2025-07-30 11:01:51.588639
# 9231   61.079233    61.070477 2025-07-30 11:01:51.588639
# 9232  -64.929766   -64.929766 2025-07-30 11:01:51.588639
#
# [9233 rows x 58 columns]

# %%
bdf.add_website_data()
# Out:
# Downloading data:  90%|████████▉ | 8292/9233 [58:12<06:36,  2.37it/s]
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\requests\models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\anaconda3\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File ~\anaconda3\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File ~\anaconda3\Lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 bdf.add_website_data()
#
# File ~\bolides\bolides\bdf.py:816, in BolideDataFrame.add_website_data(self, ids)
#     814 # get the data from the website by passing the ids
#     815 from .sources import glm_website_event
# --> 816 data = glm_website_event(ids)
#     818 # initialize empty columns in the BolideDataFrame
#     819 cols = data.keys()
#
# File ~\bolides\bolides\sources.py:264, in glm_website_event(ids)
#     259 data = {'integrated_energy_g16': [], 'integrated_energy_g17': [], 'integrated_energy_g18': [], 'integrated_energy_g19': [], 'lightcurves': []}
#     261 for bid in tqdm(ids, "Downloading data"):  # for each bolide
#     262
#     263     # pull data from website
# --> 264     web_data = requests.get(API_ENDPOINT_EVENT + bid).json()['data'][0]['attachments']
#     265     row_lcs = []
#     267     # dict to store integrated energies for this event
#     268     # initialize as nan to represent lack of data
#
# File ~\anaconda3\Lib\site-packages\requests\models.py:978, in Response.json(self, **kwargs)
#     974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 978     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
